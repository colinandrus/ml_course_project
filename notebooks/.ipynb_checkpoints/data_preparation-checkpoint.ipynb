# %%
import numpy as np 
import pandas as pd 
import random
import matplotlib.pyplot as plt 
import os
pd.set_option('display.max_rows', 200)
# %matplotlib inline

# %% [markdown]
# # Import Data

# %%
# define folder where data resides 
DATAFOLDER = "/Users/snuffles753/Documents/NYU-GSAS/ds1003/term-project/data"

# %% [markdown]
# ### Appeals

# %%
# main table 
tblAppeal = pd.read_csv(os.path.join(DATAFOLDER, 'raw/tblAppeal.csv'), low_memory=False) 
print(tblAppeal.info())
tblAppeal.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870388 entries, 0 to 870387
# Data columns (total 17 columns):
# idnAppeal             870388 non-null int64
# idncase               868758 non-null float64
# idnProceeding         776380 non-null float64
# strAppealCategory     870388 non-null object
# strAppealType         870388 non-null object
# datAppealFiled        870226 non-null object
# strFiledBy            870378 non-null object
# datAttorneyE27        521008 non-null object
# datBIADecision        847196 non-null object
# strBIADecision        847180 non-null object
# strBIADecisionType    822882 non-null object
# strCaseType           824855 non-null object
# strLang               773811 non-null object
# strNat                777004 non-null object
# strProceedingIHP      367364 non-null object
# strCustody            666356 non-null object
# strProbono            1880 non-null object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 112.9+ MB
# None
#         idnAppeal    idncase  idnProceeding strAppealCategory  \
# 99175       99277  3220848.0      1604139.0                IJ
# 559373    4731192  5470520.0            NaN                DD
# 489370    4658214  3844207.0      2230507.0                IJ
# 65556       65627  3190868.0      1568813.0                IJ
# 431867    4598677  4249697.0      2777953.0                IJ
#
#                     strAppealType       datAppealFiled strFiledBy  \
# 99175                 Case Appeal  1996-01-18 00:00:00          A
# 559373  DD Visa                    2005-09-13 00:00:00          A
# 489370                    MTR BIA  2004-11-01 00:00:00          A
# 65556                 Case Appeal  1994-05-11 00:00:00          A
# 431867                Case Appeal  2003-09-29 00:00:00          A
#
#              datAttorneyE27       datBIADecision strBIADecision  \
# 99175   1996-01-18 00:00:00  1997-08-05 00:00:00            DIS
# 559373                  NaN  2006-04-13 00:00:00            DIS
# 489370                  NaN  2004-12-30 00:00:00            DEN
# 65556                   NaN  1999-08-27 00:00:00            TPS
# 431867  2003-09-29 00:00:00  2004-12-03 00:00:00            DIS
#
#        strBIADecisionType strCaseType strLang strNat strProceedingIHP  \
# 99175                   R         EXC     BEN     BG              NaN
# 559373                  P         DDC     NaN    NaN              NaN
# 489370                  P         RMV     CRE     HA
# 65556                   P         DEP      SP     HO              NaN
# 431867                  R         RMV      SP     CO
#
#        strCustody strProbono
# 99175         NaN        NaN
# 559373        NaN        NaN
# 489370          N        NaN
# 65556         NaN        NaN
# 431867          R        NaN

# %%
# drop appeals with no case number, proceeding number, or decision 
tblAppeal.dropna(subset=['idncase', 'idnProceeding', 'strBIADecision'], inplace=True) 
tblAppeal = tblAppeal[tblAppeal['idnProceeding'] != 0] # drop zeros 

# convert indexes to integers 
tblAppeal['idncase'] = tblAppeal['idncase'].astype(int) 
tblAppeal['idnProceeding'] = tblAppeal['idnProceeding'].astype(int) 
tblAppeal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 755222 entries, 0 to 869457
# Data columns (total 17 columns):
# idnAppeal             755222 non-null int64
# idncase               755222 non-null int64
# idnProceeding         755222 non-null int64
# strAppealCategory     755222 non-null object
# strAppealType         755222 non-null object
# datAppealFiled        755060 non-null object
# strFiledBy            755212 non-null object
# datAttorneyE27        478717 non-null object
# datBIADecision        755222 non-null object
# strBIADecision        755222 non-null object
# strBIADecisionType    731103 non-null object
# strCaseType           755180 non-null object
# strLang               752329 non-null object
# strNat                754061 non-null object
# strProceedingIHP      365943 non-null object
# strCustody            643730 non-null object
# strProbono            1842 non-null object
# dtypes: int64(3), object(14)
# memory usage: 103.7+ MB

# %%
# format column types 
tblAppeal['datAppealFiled_dt'] = pd.to_datetime(tblAppeal['datAppealFiled'], errors='coerce')
tblAppeal['datBIADecision_dt'] = pd.to_datetime(tblAppeal['datBIADecision'], errors='coerce')
tblAppeal['datAppealFiled_year'] = tblAppeal['datAppealFiled_dt'].dt.year

# %%
# code lookup tables 
bia_appeal_category = pd.read_excel(os.path.join(DATAFOLDER, 'raw/BIA Appeal Data File code translations.xlsx'), 
                                    sheet_name='BIA Appeal Category', skip_footer=7)
bia_appeal_type = pd.read_excel(os.path.join(DATAFOLDER, 'raw/BIA Appeal Data File code translations.xlsx'),
                                sheet_name='BIA Appeal Type', skip_footer=3)
bia_decision_type = pd.read_excel(os.path.join(DATAFOLDER, 'raw/BIA Appeal Data File code translations.xlsx'),
                                  sheet_name='BIA decision type', skip_footer=2)
bia_decision_code = pd.read_excel(os.path.join(DATAFOLDER, 'raw/BIA Appeal Data File code translations.xlsx'),
                                  sheet_name='BIA decision code', skip_footer=2)

# %%
# join them 
tblAppeal_df = tblAppeal.merge(bia_appeal_category, how='left', left_on='strAppealCategory', right_on='Code')\
                        .rename(columns={'Description': 'strAppealCategoryDesc'}).drop('Code', axis=1)\
                        .merge(bia_appeal_type, how='left', left_on='strAppealType', right_on='Code')\
                        .rename(columns={'Description': 'strAppealTypeDesc'}).drop('Code', axis=1)\
                        .merge(bia_decision_code, how='left', left_on='strBIADecision', right_on='Code')\
                        .rename(columns={'Description': 'strBIADecisionDesc'}).drop('Code', axis=1)\
                        .merge(bia_decision_type, how='left', left_on='strBIADecisionType', right_on='Code')\
                        .rename(columns={'Description': 'strBIADecisionTypeDesc'}).drop('Code', axis=1)
print(tblAppeal_df.info()) 
tblAppeal_df.sample(10).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 755222 entries, 0 to 755221
# Data columns (total 24 columns):
# idnAppeal                 755222 non-null int64
# idncase                   755222 non-null int64
# idnProceeding             755222 non-null int64
# strAppealCategory         755222 non-null object
# strAppealType             755222 non-null object
# datAppealFiled            755060 non-null object
# strFiledBy                755212 non-null object
# datAttorneyE27            478717 non-null object
# datBIADecision            755222 non-null object
# strBIADecision            755222 non-null object
# strBIADecisionType        731103 non-null object
# strCaseType               755180 non-null object
# strLang                   752329 non-null object
# strNat                    754061 non-null object
# strProceedingIHP          365943 non-null object
# strCustody                643730 non-null object
# strProbono                1842 non-null object
# datAppealFiled_dt         755060 non-null datetime64[ns]
# datBIADecision_dt         755222 non-null datetime64[ns]
# datAppealFiled_year       755060 non-null float64
# strAppealCategoryDesc     0 non-null object
# strAppealTypeDesc         755219 non-null object
# strBIADecisionDesc        0 non-null object
# strBIADecisionTypeDesc    0 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(3), object(18)
# memory usage: 144.0+ MB
# None
#                                      25620                433712  \
# idnAppeal                             25665              4643110
# idncase                             2231876              4478888
# idnProceeding                        348809              3062180
# strAppealCategory                        IJ                   IJ
# strAppealType                   Case Appeal          Case Appeal
# datAppealFiled          1987-02-03 00:00:00  2004-07-16 00:00:00
# strFiledBy                                A                    A
# datAttorneyE27                          NaN  2004-07-16 00:00:00
# datBIADecision          1991-01-08 00:00:00  2005-08-18 00:00:00
# strBIADecision                          D30                  DIS
# strBIADecisionType                        R                    P
# strCaseType                             DEP                  RMV
# strLang                                 ENG                   SP
# strNat                                   UG                   CO
# strProceedingIHP                        NaN
# strCustody                              NaN                    N
# strProbono                              NaN                  NaN
# datAppealFiled_dt       1987-02-03 00:00:00  2004-07-16 00:00:00
# datBIADecision_dt       1991-01-08 00:00:00  2005-08-18 00:00:00
# datAppealFiled_year                    1987                 2004
# strAppealCategoryDesc                   NaN                  NaN
# strAppealTypeDesc               Case Appeal          Case Appeal
# strBIADecisionDesc                      NaN                  NaN
# strBIADecisionTypeDesc                  NaN                  NaN
#
#                                      18207                332869  \
# idnAppeal                             18240              4534233
# idncase                             2455520              3651619
# idnProceeding                        633298              1999381
# strAppealCategory                        IJ                   IJ
# strAppealType                   Case Appeal              MTR BIA
# datAppealFiled          1994-12-05 00:00:00  2002-06-28 00:00:00
# strFiledBy                                A                    A
# datAttorneyE27          1994-12-05 00:00:00  2002-06-28 00:00:00
# datBIADecision          1998-03-16 00:00:00  2002-11-07 00:00:00
# strBIADecision                          DIS                  DEN
# strBIADecisionType                        R                    P
# strCaseType                             DEP                  RMV
# strLang                                  CV                   AR
# strNat                                   CV                   KU
# strProceedingIHP                        NaN
# strCustody                              NaN                    N
# strProbono                              NaN                  NaN
# datAppealFiled_dt       1994-12-05 00:00:00  2002-06-28 00:00:00
# datBIADecision_dt       1998-03-16 00:00:00  2002-11-07 00:00:00
# datAppealFiled_year                    1994                 2002
# strAppealCategoryDesc                   NaN                  NaN
# strAppealTypeDesc               Case Appeal              MTR BIA
# strBIADecisionDesc                      NaN                  NaN
# strBIADecisionTypeDesc                  NaN                  NaN
#
#                                      446745               680376  \
# idnAppeal                           4657740              4928872
# idncase                             3836116              4566694
# idnProceeding                       2221738              3168731
# strAppealCategory                        IJ                   IJ
# strAppealType                       MTR BIA              MTR BIA
# datAppealFiled          2004-10-22 00:00:00  2010-12-13 00:00:00
# strFiledBy                                A                    A
# datAttorneyE27          2004-10-22 00:00:00  2010-12-13 00:00:00
# datBIADecision          2005-03-02 00:00:00  2011-07-20 00:00:00
# strBIADecision                          DEN                  REM
# strBIADecisionType                        R                    R
# strCaseType                             RMV                  RMV
# strLang                                 SP                   IND
# strNat                                   MX                   ID
# strProceedingIHP                                             NaN
# strCustody                                N                    N
# strProbono                              NaN                  NaN
# datAppealFiled_dt       2004-10-22 00:00:00  2010-12-13 00:00:00
# datBIADecision_dt       2005-03-02 00:00:00  2011-07-20 00:00:00
# datAppealFiled_year                    2004                 2010
# strAppealCategoryDesc                   NaN                  NaN
# strAppealTypeDesc                   MTR BIA              MTR BIA
# strBIADecisionDesc                      NaN                  NaN
# strBIADecisionTypeDesc                  NaN                  NaN
#
#                                      270017               348938  \
# idnAppeal                           4462224              4551436
# idncase                             3853262              4098119
# idnProceeding                       2241240              2574513
# strAppealCategory                        IJ                   IJ
# strAppealType                   Case Appeal              MTR BIA
# datAppealFiled          2000-06-22 00:00:00  2002-11-04 00:00:00
# strFiledBy                                I                    A
# datAttorneyE27                          NaN  2002-11-04 00:00:00
# datBIADecision          2001-08-20 00:00:00  2003-01-17 00:00:00
# strBIADecision                          DIS                  DEN
# strBIADecisionType                        R                    P
# strCaseType                             RMV                  RMV
# strLang                                  SP                   SP
# strNat                                   CU                   MX
# strProceedingIHP
# strCustody                                N                    N
# strProbono                              NaN                  NaN
# datAppealFiled_dt       2000-06-22 00:00:00  2002-11-04 00:00:00
# datBIADecision_dt       2001-08-20 00:00:00  2003-01-17 00:00:00
# datAppealFiled_year                    2000                 2002
# strAppealCategoryDesc                   NaN                  NaN
# strAppealTypeDesc               Case Appeal              MTR BIA
# strBIADecisionDesc                      NaN                  NaN
# strBIADecisionTypeDesc                  NaN                  NaN
#
#                                      9320                 11156
# idnAppeal                              9335                11176
# idncase                             2266102              3443368
# idnProceeding                        392135              1754757
# strAppealCategory                        IJ                   IJ
# strAppealType                   Case Appeal          Case Appeal
# datAppealFiled          1994-08-01 00:00:00  1995-08-28 00:00:00
# strFiledBy                                A                    A
# datAttorneyE27                          NaN                  NaN
# datBIADecision          1995-02-23 00:00:00  1996-11-15 00:00:00
# strBIADecision                          DIS                  D30
# strBIADecisionType                        P                    R
# strCaseType                             DEP                  DEP
# strLang                                 LAO                   SP
# strNat                                   LA                   GT
# strProceedingIHP                        NaN                  NaN
# strCustody                                R                  NaN
# strProbono                              NaN                  NaN
# datAppealFiled_dt       1994-08-01 00:00:00  1995-08-28 00:00:00
# datBIADecision_dt       1995-02-23 00:00:00  1996-11-15 00:00:00
# datAppealFiled_year                    1994                 1995
# strAppealCategoryDesc                   NaN                  NaN
# strAppealTypeDesc               Case Appeal          Case Appeal
# strBIADecisionDesc                      NaN                  NaN
# strBIADecisionTypeDesc                  NaN                  NaN

# %%
# some strBIADecision don't have corresponding code translations; to remove 
print(tblAppeal_df[pd.isnull(tblAppeal_df['strBIADecisionDesc'])]['strBIADecision'].value_counts()) 
tblAppeal_df.dropna(subset=['strBIADecisionDesc'], inplace=True)
tblAppeal_df.info()
# Out:
# DIS    212374
# REM    108917
# DEN     97799
# SAF     59244
# D30     47006
# WDL     28587
# DVD     28381
# SAV     27481
# OTH     19796
# GRN     17526
# TPS     16235
# NJU     15166
# SUS     14421
# TER      9831
# SUD      9468
# BCR      8522
# DSO      5987
# CON      5695
# DUT      5160
# MBD      3302
# DED      2107
# GNR      1850
# CPG      1704
# ABC      1606
# REJ      1319
# APD      1170
# SED      1072
# SND       723
# SAD       523
# GRS       431
# DNS       421
# ADM       355
# OTS       260
# DMO       238
# CPC        90
# MB         88
# SNC        82
# SOD        60
# AFD        54
# RET        52
# ADR        45
# ADD        18
# CGR        16
# TPD        16
# REV        13
# WPD         5
# SUP         4
#             2
# Name: strBIADecision, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 24 columns):
# idnAppeal                 0 non-null int64
# idncase                   0 non-null int64
# idnProceeding             0 non-null int64
# strAppealCategory         0 non-null object
# strAppealType             0 non-null object
# datAppealFiled            0 non-null object
# strFiledBy                0 non-null object
# datAttorneyE27            0 non-null object
# datBIADecision            0 non-null object
# strBIADecision            0 non-null object
# strBIADecisionType        0 non-null object
# strCaseType               0 non-null object
# strLang                   0 non-null object
# strNat                    0 non-null object
# strProceedingIHP          0 non-null object
# strCustody                0 non-null object
# strProbono                0 non-null object
# datAppealFiled_dt         0 non-null datetime64[ns]
# datBIADecision_dt         0 non-null datetime64[ns]
# datAppealFiled_year       0 non-null float64
# strAppealCategoryDesc     0 non-null object
# strAppealTypeDesc         0 non-null object
# strBIADecisionDesc        0 non-null object
# strBIADecisionTypeDesc    0 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(3), object(18)
# memory usage: 0.0+ bytes

# %% [markdown]
# ### Master Proceedings

# %%
master = pd.read_csv(os.path.join(DATAFOLDER, 'raw/master.csv')) 
print(master.info())
master.sample(5)
# Out:
# /Users/snuffles753/anaconda/envs/py3k/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6084437 entries, 0 to 6084436
# Data columns (total 16 columns):
# idncase             float64
# nat                 object
# case_type           object
# c_asy_type          object
# idnproceeding       object
# base_city_code      object
# hearing_loc_code    object
# dec_type            object
# dec_code            object
# other_comp          object
# osc_date            object
# input_date          object
# comp_date           object
# attorney_flag       float64
# ij_code             object
# tracid              float64
# dtypes: float64(3), object(13)
# memory usage: 742.7+ MB
# None
#            idncase nat case_type c_asy_type idnproceeding base_city_code  \
# 2587313  4053003.0  SL       RMV          I       2508461            NYC
# 3306728  4582098.0  HA       RMV          I       3404669            MIA
# 3747632  5297362.0  BR       RMV        NaN       3670709            SNA
# 1905313  3528563.0  ES       DEP          I       1854618            LOS
# 2274637  3824596.0  CE       RMV        NaN       2207606            CHI
#
#         hearing_loc_code dec_type dec_code other_comp   osc_date input_date  \
# 2587313              NYC      NaN      NaN          C  19MAY2000  02JUN2000
# 3306728              MIA        O        R        NaN  10JUN2003  12JUN2003
# 3747632              SNA        W        X        NaN  05JUL2005  02AUG2005
# 1905313              LOS        W        D        NaN  24MAY1996  12JUN1996
# 2274637              CHI        W        X        NaN  04JAN1999  02FEB1999
#
#          comp_date  attorney_flag ij_code  tracid
# 2587313  09AUG2000            1.0     WFJ   276.0
# 3306728  25AUG2004            1.0     DNS   128.0
# 3747632  10AUG2005            NaN     GPM   183.0
# 1905313  26JUN1996            NaN     SLS   101.0
# 2274637  04MAY1999            NaN     CMZ    32.0

# %%
# check missing data 
master.isnull().sum()
# Out:
# idncase                  14
# nat                   16775
# case_type                15
# c_asy_type          4449366
# idnproceeding             0
# base_city_code           24
# hearing_loc_code       1516
# dec_type            1519549
# dec_code            1674748
# other_comp          4744870
# osc_date              33353
# input_date            29744
# comp_date            335076
# attorney_flag       3044591
# ij_code               39598
# tracid               341914
# dtype: int64

# %%
# look up tables 
master_case_type = pd.read_csv(os.path.join(DATAFOLDER, 'raw/master_case_type.csv'))
master_decision_type = pd.read_csv(os.path.join(DATAFOLDER, 'raw/master_decision_type.csv'))
master_decision_on_proceeding = pd.read_csv(os.path.join(DATAFOLDER, 'raw/master_decision_on_proceeding.csv'), 
                                            skipfooter=2, engine='python')
master_decision_on_proceeding.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'], axis=1, inplace=True)

# %%
# add column to indicate whether decision was listed in dec_code or other_comp 
master['dec_col'] = np.where(pd.notnull(master['dec_code']), 'C', 'O') 
master['dec_judge'] = np.where(pd.notnull(master['dec_code']), master['dec_code'], master['other_comp'])

# %%
# join to look up tables
master_df = master.merge(master_decision_type, how='left', left_on='dec_type', right_on='strCode')\
                  .rename(columns={'strDescription': 'dec_type_str'}).drop('strCode', axis=1)\
                  .merge(master_case_type, how='left', left_on='case_type', right_on='strCode')\
                  .rename(columns={'strDescription': 'case_type_str'}).drop('strCode', axis=1)\
                  .merge(master_decision_on_proceeding, how='left', left_on=['case_type', 'dec_judge', 'dec_col'], 
                         right_on=['strCaseType', 'strDecCode', 'strDecType'])\
                  .rename(columns={'strDecDescription': 'dec_code_str'}).drop(['strCaseType', 'strDecCode', 'strDecType'], axis=1)
master_df.sample(5)
# Out:
#            idncase nat case_type c_asy_type idnproceeding base_city_code  \
# 1180524  2946706.0  BG       RMV          I       1273285            NYC
# 4117162  5616179.0  MX       RMV        NaN       4194884            NYC
# 4804315  6188702.0  CH       RMV          E       4783557            SNA
# 4639716  6050992.0  MX       RMV        NaN       4631716            ELP
# 5273923  6579138.0  MX       RMV        NaN       5276561            SEA
#
#         hearing_loc_code dec_type dec_code other_comp         ...           \
# 1180524              NYX        O        X        NaN         ...
# 4117162              NYC        O        V        NaN         ...
# 4804315              PSD      NaN      NaN          T         ...
# 4639716              ELP        O        X        NaN         ...
# 5273923              SEA        O        R        NaN         ...
#
#         input_date  comp_date attorney_flag  ij_code tracid  dec_col  \
# 1180524  09MAR2001  06APR2001           1.0      WCP   62.0        C
# 4117162  05APR2007  20SEP2007           1.0      VGU  144.0        C
# 4804315  12MAR2009  22APR2009           1.0      GPM  183.0        O
# 4639716  22SEP2008  01SEP2010           1.0      RSH   52.0        C
# 5273923  20AUG2010  29DEC2011           1.0       KJ  211.0        C
#
#         dec_judge   dec_type_str case_type_str         dec_code_str
# 1180524         X  oral decision       Removal               Remove
# 4117162         V  oral decision       Removal  Voluntary Departure
# 4804315         T            NaN       Removal             Transfer
# 4639716         X  oral decision       Removal               Remove
# 5273923         R  oral decision       Removal       Relief Granted
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Master Proceedings (processed data from Daniel Chen)

# %%
import sys

reader = pd.read_stata(os.path.join(DATAFOLDER,'decision_sched_merge_adjdate.dta'), iterator=True)
df = pd.DataFrame()
chunk_size = 100*1000
try:
    chunk = reader.get_chunk(chunk_size)
    with open(os.path.join(DATAFOLDER,'decision_sched_merge_adjdate.csv'), 'a') as f:
        first = True
        while len(chunk) > 0:
            if first:
                chunk.to_csv(f, header=True)
                first = False
            else:
                chunk.to_csv(f, header=False)
#             df = df.append(chunk, ignore_index=True)
            chunk = reader.get_chunk(chunk_size)
            print('.')
            sys.stdout.flush()
except (StopIteration, KeyboardInterrupt):
    pass

master_dchen.info()
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b688312a8715> in <module>()
#      21     pass
#      22
# ---> 23 master_dchen.info()
#
# NameError: name 'master_dchen' is not defined

# %%
master_dchen = pd.read_csv(os.path.join(DATAFOLDER,'decision_sched_merge_adjdate.csv'), 
                           low_memory=False) 
master_dchen.info()
# Out:
# /Users/snuffles753/anaconda/envs/py3k/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (52,85,86,88,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5664753 entries, 0 to 5664752
# Columns: 107 entries, Unnamed: 0 to flag_datemismatch
# dtypes: float64(52), int64(11), object(44)
# memory usage: 4.5+ GB

# %%
# check for nulls 
master_dchen.isnull().sum()
# Out:
# idncase                                 0
# nat                                     0
# case_type                               0
# c_asy_type                              0
# idnproceeding                           0
# base_city_code                          0
# hearing_loc_code                        0
# dec_type                                0
# dec_code                                0
# other_comp                              0
# attorney_flag                     2907462
# ij_code                                 0
# tracid                             248615
# comp_year                               0
# comp_month                              0
# comp_day                                0
# comp_date                               0
# osc_year                            32420
# osc_month                           32420
# osc_day                             32420
# osc_date                            32420
# input_year                          27549
# input_month                         27549
# input_day                           27549
# input_date                          27549
# lawyer                                  0
# defensive                         4156705
# affirmative                       4156705
# case_type_string                        0
# _mcase                                  0
# dec_type_string                         0
# _mdectype                               0
# outcome_recorded_in_field               0
# dec_string                              0
# _mdecproceeddec                         0
# _mdecproceedoth                         0
# nat_string                              0
# _mnat                                   0
# base_city_street                        0
# base_city_string                        0
# base_city_state                         0
# base_city_zip5                          0
# base_city_zip4                     429285
# base_city_phone                         0
# _mbasecity                              0
# hearing_loc_string1                     0
# hearing_loc_string2                     0
# hearing_loc_street                      0
# hearing_loc_city                        0
# hearing_loc_state                       0
# hearing_loc_zip5                     2801
# hearing_loc_phone                       0
# _mhearingloc                            0
# judge_name_caps                         0
# _mlookupijcode                          0
# cityid                                  0
# judgeid                                 0
# natid                               27544
# venue_change                          332
# deport                                332
# relief_granted                        332
# remove                                332
# terminated                            332
# voluntary_departure                   332
# oral                              1150629
# written                           1150629
# deport_form                       1150629
# voluntary_form                    1150629
# deportation_proceeding                112
# exclusion_proceeding                  112
# removal_proceeding                    112
# asylum_only_proceeding                112
# withholding_only_proceeding           112
# idncode                                 0
# strdescription_chicago                  0
# flag_decisionerror_strdes         4451881
# decision1_chicago                       0
# grantordeny_chicago               5055262
# flag_decisionerror_idncaseproc    4451881
# decision2_chicago                       0
# grant_asylum_chicago              5095875
# grant_withhold_chicago            5281083
# grant_cat_chicago                 5469762
# _mmasterappl                            0
# strdescription_holger                   0
# decision1_holger                        0
# grantordeny_holger                5207993
# decision2_holger                        0
# grant_asylum_holger               5230454
# grant_withhold_holger             5355571
# grant_cat_holger                  5498503
# _mmasterappl2                           0
# adj_hearing_loc_code                    0
# adj_base_city_code                      0
# adj_time_start                      73671
# adj_date                            72842
# adj_input_date                      72842
# adj_osc_date                        82823
# flag_earlystarttime                 72842
# eoirattyid                        3460334
# alienattyid                       3390990
# _mschedcompdate                         0
# flag_mismatch_base_city             72842
# flag_mismatch_hearing               73922
# _mscheddatetime                   4781556
# flag_datemismatch                 4781556
# dtype: int64

# %%
master_dchen.sample(3).T
# Out:
#                                                     4494264  \
# idncase                                             6687724
# nat                                                      MX
# case_type                                               RMV
# c_asy_type
# idnproceeding                                       5422859
# base_city_code                                          LVG
# hearing_loc_code                                        LVG
# dec_type                                                  O
# dec_code                                                  X
# other_comp
# attorney_flag                                           NaN
# ij_code                                                 JLR
# tracid                                                  100
# comp_year                                              2011
# comp_month                                                2
# comp_day                                                 23
# comp_date                                             18681
# osc_year                                               2011
# osc_month                                                 2
# osc_day                                                   8
# osc_date                                              18666
# input_year                                             2011
# input_month                                               2
# input_day                                                 8
# input_date                                            18666
# lawyer                                                    0
# defensive                                               NaN
# affirmative                                             NaN
# case_type_string                                    REMOVAL
# _mcase                                          matched (3)
# dec_type_string                               ORAL DECISION
# _mdectype                                       matched (3)
# outcome_recorded_in_field                                 C
# dec_string                                           REMOVE
# _mdecproceeddec                                 matched (3)
# _mdecproceedoth                             master only (1)
# nat_string                                           MEXICO
# _mnat                                           matched (3)
# base_city_street                3365 PEPPER LANE, SUITE 200
# base_city_string                                  LAS VEGAS
# base_city_state                                          NV
# base_city_zip5                                        89120
# base_city_zip4                                            0
# base_city_phone                                 7.02458e+08
# _mbasecity                                      matched (3)
# hearing_loc_string1                       LAS VEGAS, NEVADA
# hearing_loc_string2                       IMMIGRATION COURT
# hearing_loc_street              3365 PEPPER LANE, SUITE 200
# hearing_loc_city                                  LAS VEGAS
# hearing_loc_state                                        NV
# hearing_loc_zip5                                      89120
# hearing_loc_phone                                 702458227
# _mhearingloc                                    matched (3)
# judge_name_caps                            JEFFREY L. ROMIG
# _mlookupijcode                                  matched (3)
# cityid                                                   29
# judgeid                                                 196
# natid                                                   152
# venue_change                                              0
# deport                                                    0
# relief_granted                                            0
# remove                                                    1
# terminated                                                0
# voluntary_departure                                       0
# oral                                                      1
# written                                                   0
# deport_form                                               0
# voluntary_form                                            0
# deportation_proceeding                                    0
# exclusion_proceeding                                      0
# removal_proceeding                                        1
# asylum_only_proceeding                                    0
# withholding_only_proceeding                               0
# idncode                                         5.25681e+06
# strdescription_chicago
# flag_decisionerror_strdes                               NaN
# decision1_chicago
# grantordeny_chicago                                     NaN
# flag_decisionerror_idncaseproc                          NaN
# decision2_chicago
# grant_asylum_chicago                                    NaN
# grant_withhold_chicago                                  NaN
# grant_cat_chicago                                       NaN
# _mmasterappl                                master only (1)
# strdescription_holger
# decision1_holger
# grantordeny_holger                                      NaN
# decision2_holger
# grant_asylum_holger                                     NaN
# grant_withhold_holger                                   NaN
# grant_cat_holger                                        NaN
# _mmasterappl2                               master only (1)
# adj_hearing_loc_code                                    LVG
# adj_base_city_code                                      LVG
# adj_time_start                                         1300
# adj_date                                              18681
# adj_input_date                                        18668
# adj_osc_date                                          18666
# flag_earlystarttime                                       0
# eoirattyid                                              NaN
# alienattyid                                             NaN
# _mschedcompdate                                 matched (3)
# flag_mismatch_base_city                                   0
# flag_mismatch_hearing                                     0
# _mscheddatetime                                         NaN
# flag_datemismatch                                       NaN
#
#                                                        2715672  \
# idncase                                                4402533
# nat                                                         JM
# case_type                                                  RMV
# c_asy_type
# idnproceeding                                          2969197
# base_city_code                                             ORL
# hearing_loc_code                                           BDC
# dec_type
# dec_code
# other_comp                                                   T
# attorney_flag                                                1
# ij_code                                                    RKM
# tracid                                                      21
# comp_year                                                 2001
# comp_month                                                   5
# comp_day                                                    23
# comp_date                                                15118
# osc_year                                                  1998
# osc_month                                                    6
# osc_day                                                      2
# osc_date                                                 14032
# input_year                                                2001
# input_month                                                  2
# input_day                                                   28
# input_date                                               15034
# lawyer                                                       1
# defensive                                                  NaN
# affirmative                                                NaN
# case_type_string                                       REMOVAL
# _mcase                                             matched (3)
# dec_type_string
# _mdectype                                      master only (1)
# outcome_recorded_in_field                                    O
# dec_string                                            TRANSFER
# _mdecproceeddec                                master only (1)
# _mdecproceedoth                            missing updated (4)
# nat_string                                             JAMAICA
# _mnat                                              matched (3)
# base_city_street                   3535 LAWTON ROAD, SUITE 200
# base_city_string                                       ORLANDO
# base_city_state                                             FL
# base_city_zip5                                           32803
# base_city_zip4                                               0
# base_city_phone                                    4.07649e+09
# _mbasecity                                         matched (3)
# hearing_loc_string1                 BRADENTON DETENTION CENTER
# hearing_loc_string2                 BRADENTON DETENTION CENTER
# hearing_loc_street              80 NORTH HUGHEY AVD, SUITE 203
# hearing_loc_city                                       ORLANDO
# hearing_loc_state                                           FL
# hearing_loc_zip5                                         32801
# hearing_loc_phone                                   4076486565
# _mhearingloc                                       matched (3)
# judge_name_caps                                R. KEVIN MCHUGH
# _mlookupijcode                                     matched (3)
# cityid                                                      38
# judgeid                                                    337
# natid                                                      114
# venue_change                                                 0
# deport                                                       0
# relief_granted                                               0
# remove                                                       0
# terminated                                                   0
# voluntary_departure                                          0
# oral                                                       NaN
# written                                                    NaN
# deport_form                                                NaN
# voluntary_form                                             NaN
# deportation_proceeding                                       0
# exclusion_proceeding                                         0
# removal_proceeding                                           1
# asylum_only_proceeding                                       0
# withholding_only_proceeding                                  0
# idncode                                             2.9257e+06
# strdescription_chicago
# flag_decisionerror_strdes                                  NaN
# decision1_chicago
# grantordeny_chicago                                        NaN
# flag_decisionerror_idncaseproc                             NaN
# decision2_chicago
# grant_asylum_chicago                                       NaN
# grant_withhold_chicago                                     NaN
# grant_cat_chicago                                          NaN
# _mmasterappl                                   master only (1)
# strdescription_holger
# decision1_holger
# grantordeny_holger                                         NaN
# decision2_holger
# grant_asylum_holger                                        NaN
# grant_withhold_holger                                      NaN
# grant_cat_holger                                           NaN
# _mmasterappl2                                  master only (1)
# adj_hearing_loc_code                                       BDC
# adj_base_city_code                                         ORL
# adj_time_start                                            1000
# adj_date                                                 15118
# adj_input_date                                           17340
# adj_osc_date                                             14032
# flag_earlystarttime                                          0
# eoirattyid                                               64135
# alienattyid                                               8781
# _mschedcompdate                                    matched (3)
# flag_mismatch_base_city                                      0
# flag_mismatch_hearing                                        0
# _mscheddatetime                                            NaN
# flag_datemismatch                                          NaN
#
#                                                       3057914
# idncase                                               4907282
# nat                                                        CS
# case_type                                                 RMV
# c_asy_type
# idnproceeding                                         3330761
# base_city_code                                            ELP
# hearing_loc_code                                          ELP
# dec_type                                                    O
# dec_code                                                    X
# other_comp
# attorney_flag                                             NaN
# ij_code                                                   RSH
# tracid                                                     52
# comp_year                                                2005
# comp_month                                                  2
# comp_day                                                   10
# comp_date                                               16477
# osc_year                                                 2004
# osc_month                                                   8
# osc_day                                                    12
# osc_date                                                16295
# input_year                                               2004
# input_month                                                 9
# input_day                                                   8
# input_date                                              16322
# lawyer                                                      0
# defensive                                                 NaN
# affirmative                                               NaN
# case_type_string                                      REMOVAL
# _mcase                                            matched (3)
# dec_type_string                                 ORAL DECISION
# _mdectype                                         matched (3)
# outcome_recorded_in_field                                   C
# dec_string                                             REMOVE
# _mdecproceeddec                                   matched (3)
# _mdecproceedoth                               master only (1)
# nat_string                                         COSTA RICA
# _mnat                                             matched (3)
# base_city_street                700 E. SAN ANTONIO, SUITE 750
# base_city_string                                      EL PASO
# base_city_state                                            TX
# base_city_zip5                                          79901
# base_city_zip4                                              0
# base_city_phone                                   9.15782e+09
# _mbasecity                                        matched (3)
# hearing_loc_string1                            EL PASO, TEXAS
# hearing_loc_string2                         IMMIGRATION COURT
# hearing_loc_street              700 E. SAN ANTONIO, SUITE 750
# hearing_loc_city                                      EL PASO
# hearing_loc_state                                          TX
# hearing_loc_zip5                                        79901
# hearing_loc_phone                                  9157824550
# _mhearingloc                                      matched (3)
# judge_name_caps                               ROBERT S. HOUGH
# _mlookupijcode                                    matched (3)
# cityid                                                     16
# judgeid                                                   354
# natid                                                      52
# venue_change                                                0
# deport                                                      0
# relief_granted                                              0
# remove                                                      1
# terminated                                                  0
# voluntary_departure                                         0
# oral                                                        1
# written                                                     0
# deport_form                                                 0
# voluntary_form                                              0
# deportation_proceeding                                      0
# exclusion_proceeding                                        0
# removal_proceeding                                          1
# asylum_only_proceeding                                      0
# withholding_only_proceeding                                 0
# idncode                                           3.27033e+06
# strdescription_chicago
# flag_decisionerror_strdes                                 NaN
# decision1_chicago
# grantordeny_chicago                                       NaN
# flag_decisionerror_idncaseproc                            NaN
# decision2_chicago
# grant_asylum_chicago                                      NaN
# grant_withhold_chicago                                    NaN
# grant_cat_chicago                                         NaN
# _mmasterappl                                  master only (1)
# strdescription_holger
# decision1_holger
# grantordeny_holger                                        NaN
# decision2_holger
# grant_asylum_holger                                       NaN
# grant_withhold_holger                                     NaN
# grant_cat_holger                                          NaN
# _mmasterappl2                                 master only (1)
# adj_hearing_loc_code                                      ELP
# adj_base_city_code                                        ELP
# adj_time_start                                            830
# adj_date                                                16477
# adj_input_date                                          17234
# adj_osc_date                                            16295
# flag_earlystarttime                                         0
# eoirattyid                                                NaN
# alienattyid                                               NaN
# _mschedcompdate                                   matched (3)
# flag_mismatch_base_city                                     0
# flag_mismatch_hearing                                       0
# _mscheddatetime                                           NaN
# flag_datemismatch                                         NaN

# %%
# add column to indicate whether decision was listed in dec_code or other_comp 
master_dchen['dec_col'] = np.where(pd.notnull(master_dchen['dec_code']), 'C', 'O') 
master_dchen['dec_judge'] = np.where(pd.notnull(master_dchen['dec_code']), master_dchen['dec_code'], master_dchen['other_comp'])

# %%
# join to look up tables
master_dchen_df = master_dchen.merge(master_decision_type, how='left', left_on='dec_type', right_on='strCode')\
                              .rename(columns={'strDescription': 'dec_type_str'}).drop('strCode', axis=1)\
                              .merge(master_case_type, how='left', left_on='case_type', right_on='strCode')\
                              .rename(columns={'strDescription': 'case_type_str'}).drop('strCode', axis=1)\
                              .merge(master_decision_on_proceeding, how='left', 
                                     left_on=['case_type', 'dec_judge', 'dec_col'], 
                                     right_on=['strCaseType', 'strDecCode', 'strDecType'])\
                              .rename(columns={'strDecDescription': 'dec_code_str'}).drop(['strCaseType', 'strDecCode', 'strDecType'], axis=1)
master_dchen_df.sample(3).T
# Out:
#                                                        5552120  \
# idncase                                                6806458
# nat                                                         SL
# case_type                                                  RMV
# c_asy_type
# idnproceeding                                          5583990
# base_city_code                                             BAL
# hearing_loc_code                                           BAL
# dec_type                                                     W
# dec_code
# other_comp                                                   A
# attorney_flag                                                1
# ij_code                                                    JFG
# tracid                                                      10
# comp_year                                                 2012
# comp_month                                                   6
# comp_day                                                    27
# comp_date                                                19171
# osc_year                                                  2011
# osc_month                                                    7
# osc_day                                                     20
# osc_date                                                 18828
# input_year                                                2011
# input_month                                                  7
# input_day                                                   26
# input_date                                               18834
# lawyer                                                       1
# defensive                                                  NaN
# affirmative                                                NaN
# case_type_string                                       REMOVAL
# _mcase                                             matched (3)
# dec_type_string                               WRITTEN DECISION
# _mdectype                                          matched (3)
# outcome_recorded_in_field                                    O
# dec_string                      ADMINISTRATIVE CLOSING - OTHER
# _mdecproceeddec                                master only (1)
# _mdecproceedoth                            missing updated (4)
# nat_string                                        SIERRA LEONE
# _mnat                                              matched (3)
# base_city_street                    31 HOPKINS PLAZA, ROOM 440
# base_city_string                                     BALTIMORE
# base_city_state                                             MD
# base_city_zip5                                           21201
# base_city_zip4                                               0
# base_city_phone                                    4.10962e+09
# _mbasecity                                         matched (3)
# hearing_loc_string1                        BALTIMORE, MARYLAND
# hearing_loc_string2                          IMMIGRATION COURT
# hearing_loc_street                  31 HOPKINS PLAZA, ROOM 440
# hearing_loc_city                                     BALTIMORE
# hearing_loc_state                                           MD
# hearing_loc_zip5                                         21201
# hearing_loc_phone                                   4109623092
# _mhearingloc                                       matched (3)
# judge_name_caps                           JOHN F. GOSSART, JR.
# _mlookupijcode                                     matched (3)
# cityid                                                       4
# judgeid                                                    184
# natid                                                      196
# venue_change                                                 0
# deport                                                       0
# relief_granted                                               0
# remove                                                       0
# terminated                                                   0
# voluntary_departure                                          0
# oral                                                         0
# written                                                      1
# deport_form                                                  0
# voluntary_form                                               0
# deportation_proceeding                                       0
# exclusion_proceeding                                         0
# removal_proceeding                                           1
# asylum_only_proceeding                                       0
# withholding_only_proceeding                                  0
# idncode                                            5.41334e+06
# strdescription_chicago
# flag_decisionerror_strdes                                  NaN
# decision1_chicago
# grantordeny_chicago                                        NaN
# flag_decisionerror_idncaseproc                             NaN
# decision2_chicago
# grant_asylum_chicago                                       NaN
# grant_withhold_chicago                                     NaN
# grant_cat_chicago                                          NaN
# _mmasterappl                                   master only (1)
# strdescription_holger
# decision1_holger
# grantordeny_holger                                         NaN
# decision2_holger
# grant_asylum_holger                                        NaN
# grant_withhold_holger                                      NaN
# grant_cat_holger                                           NaN
# _mmasterappl2                                  master only (1)
# adj_hearing_loc_code                                       BAL
# adj_base_city_code                                         BAL
# adj_time_start                                            1330
# adj_date                                                 19171
# adj_input_date                                           18981
# adj_osc_date                                             18828
# flag_earlystarttime                                          0
# eoirattyid                                               96820
# alienattyid                                              16873
# _mschedcompdate                                master only (1)
# flag_mismatch_base_city                                      0
# flag_mismatch_hearing                                        0
# _mscheddatetime                            missing updated (4)
# flag_datemismatch                                            0
# dec_col                                                      C
# dec_judge
# dec_type_str                                  written decision
# case_type_str                                          Removal
# dec_code_str                                               NaN
#
#                                                       5249888  \
# idncase                                               5884085
# nat                                                        GT
# case_type                                                 RMV
# c_asy_type
# idnproceeding                                         4400190
# base_city_code                                            ATL
# hearing_loc_code                                          ATD
# dec_type
# dec_code
# other_comp                                                  T
# attorney_flag                                               1
# ij_code                                                   JDP
# tracid                                                    287
# comp_year                                                2007
# comp_month                                                 12
# comp_day                                                   26
# comp_date                                               17526
# osc_year                                                 2007
# osc_month                                                  12
# osc_day                                                     6
# osc_date                                                17506
# input_year                                               2007
# input_month                                                12
# input_day                                                  21
# input_date                                              17521
# lawyer                                                      1
# defensive                                                 NaN
# affirmative                                               NaN
# case_type_string                                      REMOVAL
# _mcase                                            matched (3)
# dec_type_string
# _mdectype                                     master only (1)
# outcome_recorded_in_field                                   O
# dec_string                                           TRANSFER
# _mdecproceeddec                               master only (1)
# _mdecproceedoth                           missing updated (4)
# nat_string                                          GUATEMALA
# _mnat                                             matched (3)
# base_city_street                180 SPRING ST., SW, SUITE 241
# base_city_string                                      ATLANTA
# base_city_state                                            GA
# base_city_zip5                                          30303
# base_city_zip4                                              0
# base_city_phone                                   4.04331e+09
# _mbasecity                                        matched (3)
# hearing_loc_string1                 ATLANTA DETAINED LOCATION
# hearing_loc_string2                         IMMIGRATION COURT
# hearing_loc_street              180 SPRING ST., SW, SUITE 241
# hearing_loc_city                                      ATLANTA
# hearing_loc_state                                          GA
# hearing_loc_zip5                                   3.0303e+08
# hearing_loc_phone                                  4043310907
# _mhearingloc                                      matched (3)
# judge_name_caps                              J. DAN PELLETIER
# _mlookupijcode                                    matched (3)
# cityid                                                      3
# judgeid                                                   180
# natid                                                      94
# venue_change                                                0
# deport                                                      0
# relief_granted                                              0
# remove                                                      0
# terminated                                                  0
# voluntary_departure                                         0
# oral                                                      NaN
# written                                                   NaN
# deport_form                                               NaN
# voluntary_form                                            NaN
# deportation_proceeding                                      0
# exclusion_proceeding                                        0
# removal_proceeding                                          1
# asylum_only_proceeding                                      0
# withholding_only_proceeding                                 0
# idncode                                           4.27225e+06
# strdescription_chicago
# flag_decisionerror_strdes                                 NaN
# decision1_chicago
# grantordeny_chicago                                       NaN
# flag_decisionerror_idncaseproc                            NaN
# decision2_chicago
# grant_asylum_chicago                                      NaN
# grant_withhold_chicago                                    NaN
# grant_cat_chicago                                         NaN
# _mmasterappl                                  master only (1)
# strdescription_holger
# decision1_holger
# grantordeny_holger                                        NaN
# decision2_holger
# grant_asylum_holger                                       NaN
# grant_withhold_holger                                     NaN
# grant_cat_holger                                          NaN
# _mmasterappl2                                 master only (1)
# adj_hearing_loc_code                                      ATD
# adj_base_city_code                                        ATL
# adj_time_start                                           1230
# adj_date                                                17526
# adj_input_date                                          17520
# adj_osc_date                                           -21914
# flag_earlystarttime                                         0
# eoirattyid                                              53549
# alienattyid                                              2610
# _mschedcompdate                               master only (1)
# flag_mismatch_base_city                                     0
# flag_mismatch_hearing                                       0
# _mscheddatetime                           missing updated (4)
# flag_datemismatch                                           0
# dec_col                                                     C
# dec_judge
# dec_type_str                                              NaN
# case_type_str                                         Removal
# dec_code_str                                              NaN
#
#                                                        3846132
# idncase                                                5829605
# nat                                                         GT
# case_type                                                  RMV
# c_asy_type                                                   I
# idnproceeding                                          4331762
# base_city_code                                             MIA
# hearing_loc_code                                           MIA
# dec_type                                                     O
# dec_code                                                     X
# other_comp
# attorney_flag                                              NaN
# ij_code                                                    CJS
# tracid                                                     127
# comp_year                                                 2007
# comp_month                                                  12
# comp_day                                                     5
# comp_date                                                17505
# osc_year                                                  2007
# osc_month                                                    9
# osc_day                                                     14
# osc_date                                                 17423
# input_year                                                2007
# input_month                                                 10
# input_day                                                   11
# input_date                                               17450
# lawyer                                                       0
# defensive                                                    0
# affirmative                                                  1
# case_type_string                                       REMOVAL
# _mcase                                             matched (3)
# dec_type_string                                  ORAL DECISION
# _mdectype                                          matched (3)
# outcome_recorded_in_field                                    C
# dec_string                                              REMOVE
# _mdecproceeddec                                    matched (3)
# _mdecproceedoth                                master only (1)
# nat_string                                           GUATEMALA
# _mnat                                              matched (3)
# base_city_street                333 SOUTH MIAMI AVE., STE. 700
# base_city_string                                         MIAMI
# base_city_state                                             FL
# base_city_zip5                                           33130
# base_city_zip4                                            1904
# base_city_phone                                    3.05789e+09
# _mbasecity                                         matched (3)
# hearing_loc_string1                             MIAMI, FLORIDA
# hearing_loc_string2                          IMMIGRATION COURT
# hearing_loc_street               333 SOUTH MIAMI AVE., STE.700
# hearing_loc_city                                         MIAMI
# hearing_loc_state                                           FL
# hearing_loc_zip5                                   3.31302e+08
# hearing_loc_phone                                   3057894221
# _mhearingloc                                       matched (3)
# judge_name_caps                             CHARLES J. SANDERS
# _mlookupijcode                                     matched (3)
# cityid                                                      31
# judgeid                                                     62
# natid                                                       94
# venue_change                                                 0
# deport                                                       0
# relief_granted                                               0
# remove                                                       1
# terminated                                                   0
# voluntary_departure                                          0
# oral                                                         1
# written                                                      0
# deport_form                                                  0
# voluntary_form                                               0
# deportation_proceeding                                       0
# exclusion_proceeding                                         0
# removal_proceeding                                           1
# asylum_only_proceeding                                       0
# withholding_only_proceeding                                  0
# idncode                                            4.20754e+06
# strdescription_chicago                                  ASYLUM
# flag_decisionerror_strdes                                    0
# decision1_chicago                                      UNKNOWN
# grantordeny_chicago                                        NaN
# flag_decisionerror_idncaseproc                               0
# decision2_chicago                                      UNKNOWN
# grant_asylum_chicago                                       NaN
# grant_withhold_chicago                                     NaN
# grant_cat_chicago                                          NaN
# _mmasterappl                                       matched (3)
# strdescription_holger                                   ASYLUM
# decision1_holger                                       UNKNOWN
# grantordeny_holger                                         NaN
# decision2_holger                                       UNKNOWN
# grant_asylum_holger                                        NaN
# grant_withhold_holger                                      NaN
# grant_cat_holger                                           NaN
# _mmasterappl2                                      matched (3)
# adj_hearing_loc_code                                       MIA
# adj_base_city_code                                         MIA
# adj_time_start                                             900
# adj_date                                                 17505
# adj_input_date                                           17429
# adj_osc_date                                             17423
# flag_earlystarttime                                          0
# eoirattyid                                                 NaN
# alienattyid                                                NaN
# _mschedcompdate                                    matched (3)
# flag_mismatch_base_city                                      0
# flag_mismatch_hearing                                        0
# _mscheddatetime                                            NaN
# flag_datemismatch                                          NaN
# dec_col                                                      C
# dec_judge                                                    X
# dec_type_str                                     oral decision
# case_type_str                                          Removal
# dec_code_str                                            Remove

# %% [markdown]
# ### Master Proceedings (processed by Sagent/Dunn)

# %%
master_dunn = pd.read_csv(os.path.join(DATAFOLDER, 
                                       'AsylumAdj/data_for_model/_decision_scheduling_merge_final_converted.csv'), 
                          encoding='latin-1', low_memory=False) # gets UnicodeDecodeError otherwise 
master_dunn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602500 entries, 0 to 602499
# Columns: 182 entries, Unnamed: 0 to last_hearing_on_comp_date
# dtypes: bool(1), float64(72), int64(39), object(70)
# memory usage: 832.6+ MB

# %%
# dunn has far fewer proceedings than the original 
print "Original master has {} data points, Dunn's has {}".format(len(master_dunn), len(master))
# Out:
# Original master has 602500 data points, Dunn's has 6084437

# %%
print master_dchen.columns.tolist()
# Out:
# ['idncase', 'nat', 'case_type', 'c_asy_type', 'idnproceeding', 'base_city_code', 'hearing_loc_code', 'dec_type', 'dec_code', 'other_comp', 'attorney_flag', 'ij_code', 'tracid', 'comp_year', 'comp_month', 'comp_day', 'comp_date', 'osc_year', 'osc_month', 'osc_day', 'osc_date', 'input_year', 'input_month', 'input_day', 'input_date', 'lawyer', 'defensive', 'affirmative', 'case_type_string', '_mcase', 'dec_type_string', '_mdectype', 'outcome_recorded_in_field', 'dec_string', '_mdecproceeddec', '_mdecproceedoth', 'nat_string', '_mnat', 'base_city_street', 'base_city_string', 'base_city_state', 'base_city_zip5', 'base_city_zip4', 'base_city_phone', '_mbasecity', 'hearing_loc_string1', 'hearing_loc_string2', 'hearing_loc_street', 'hearing_loc_city', 'hearing_loc_state', 'hearing_loc_zip5', 'hearing_loc_phone', '_mhearingloc', 'judge_name_caps', '_mlookupijcode', 'cityid', 'judgeid', 'natid', 'venue_change', 'deport', 'relief_granted', 'remove', 'terminated', 'voluntary_departure', 'oral', 'written', 'deport_form', 'voluntary_form', 'deportation_proceeding', 'exclusion_proceeding', 'removal_proceeding', 'asylum_only_proceeding', 'withholding_only_proceeding', 'idncode', 'strdescription_chicago', 'flag_decisionerror_strdes', 'decision1_chicago', 'grantordeny_chicago', 'flag_decisionerror_idncaseproc', 'decision2_chicago', 'grant_asylum_chicago', 'grant_withhold_chicago', 'grant_cat_chicago', '_mmasterappl', 'strdescription_holger', 'decision1_holger', 'grantordeny_holger', 'decision2_holger', 'grant_asylum_holger', 'grant_withhold_holger', 'grant_cat_holger', '_mmasterappl2', 'adj_hearing_loc_code', 'adj_base_city_code', 'adj_time_start', 'adj_date', 'adj_input_date', 'adj_osc_date', 'flag_earlystarttime', 'eoirattyid', 'alienattyid', '_mschedcompdate', 'flag_mismatch_base_city', 'flag_mismatch_hearing', '_mscheddatetime', 'flag_datemismatch', 'dec_col', 'dec_judge']

# %%
master_dchen['asylum_only_proceeding'].value_counts()
# Out:
# 0.0    5645688
# 1.0      18953
# Name: asylum_only_proceeding, dtype: int64

# %%
master_dunn['case_type_string'].value_counts()
# Out:
# REMOVAL                 408738
# DEPORTATION             142533
# EXCLUSION                39062
# ASYLUM ONLY CASE          9669
# WITHHOLDING ONLY          2487
# CREDIBLE FEAR REVIEW         1
# Name: case_type_string, dtype: int64

# %%
master_dunn['asylum'].value_counts()
# Out:
# 1    562348
# 0     40152
# Name: asylum, dtype: int64

# %%
# determine what % of master proceedings that Dunn retained 
master_dunn_pairs = master_dunn[['idncase', 'idnproceeding']].copy()
master_dunn_pairs['in_dunn'] = 1 
master_dunn_delta = master_df[['idncase', 'idnproceeding', 'case_type_str']].merge(master_dunn_pairs, how='left', 
                                                                                   on=['idncase', 'idnproceeding']) 
master_dunn_delta['in_dunn'].fillna(0, inplace=True)
master_dunn_delta.groupby(['case_type_str'])['in_dunn'].agg(['size', np.mean])
# Out:
#                                size      mean
# case_type_str
# Asylum Only Case              19881  0.447261
# Claimed Status Review          1262  0.000000
# Continued Detention Review       42  0.000000
# Credible Fear Review           7453  0.000134
# Deportation                 1429597  0.099371
# Exclusion                    258052  0.151125
# NACARA Adjustment               470  0.000000
# Reasonable Fear Case           3611  0.000000
# Recission                      2087  0.000000
# Removal                     4354277  0.090329
# Withholding Only               7574  0.324003

# %% [markdown]
# # Determine scope of appeal case types

# %%
appeals_in_scope = tblAppeal_df.merge(master_dunn_pairs, how='left', 
                                      left_on=['idncase', 'idnProceeding'], right_on=['idncase', 'idnproceeding']) 
appeals_in_scope = appeals_in_scope.merge(master_dchen[['idncase', 'idnproceeding', 'case_type_string']], 
                                          how='left', left_on=['idncase', 'idnProceeding'], 
                                          right_on=['idncase', 'idnproceeding']) 
appeals_in_scope['in_dunn'].fillna(0, inplace=True)
appeals_in_scope['case_type_string'].fillna('NOT_MATCHED_TO_MASTER', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a2d54fb14034> in <module>()
# ----> 1 appeals_in_scope = tblAppeal_df.merge(master_dunn_pairs, how='left',
#       2                                       left_on=['idncase', 'idnProceeding'], right_on=['idncase', 'idnproceeding'])
#       3 appeals_in_scope = appeals_in_scope.merge(master_dchen[['idncase', 'idnproceeding', 'case_type_string']],
#       4                                           how='left', left_on=['idncase', 'idnProceeding'],
#       5                                           right_on=['idncase', 'idnproceeding'])
#
# NameError: name 'master_dunn_pairs' is not defined

# %%
# distribution of appeal vs. proceeding types - all
appeals_in_scope.groupby(['strAppealTypeDesc', 'case_type_string']).size().unstack().fillna(0)
# Out:
# case_type_string                    ASYLUM ONLY CASE  CLAIMED STATUS REVIEW  \
# strAppealTypeDesc
# Appeal of IJ MTR               3.0             168.0                    1.0
# Bond Appeal                    1.0              19.0                    0.0
# Bond MTR Reconsider            0.0               0.0                    0.0
# Bond MTR Reinstate             0.0               0.0                    0.0
# Bond MTR Reopen                0.0               0.0                    0.0
# Case Appeal                   10.0            4251.0                    9.0
# Circuit Court Remand           0.0             197.0                    0.0
# Interlocutory Appeal           1.0              20.0                    0.0
# MTR BIA                        2.0            1347.0                    0.0
# Reasonable Cause Appeal        0.0               0.0                    0.0
# Special Circumstances Appeal   0.0               0.0                    0.0
# Zero Bond Appeal               0.0               0.0                    0.0
#
# case_type_string              CONTINUED DETENTION REVIEW  \
# strAppealTypeDesc
# Appeal of IJ MTR                                     0.0
# Bond Appeal                                          0.0
# Bond MTR Reconsider                                  0.0
# Bond MTR Reinstate                                   0.0
# Bond MTR Reopen                                      0.0
# Case Appeal                                          0.0
# Circuit Court Remand                                 0.0
# Interlocutory Appeal                                 0.0
# MTR BIA                                              5.0
# Reasonable Cause Appeal                              1.0
# Special Circumstances Appeal                        14.0
# Zero Bond Appeal                                     0.0
#
# case_type_string              CREDIBLE FEAR REVIEW  DEPORTATION  EXCLUSION  \
# strAppealTypeDesc
# Appeal of IJ MTR                               0.0      16298.0     2058.0
# Bond Appeal                                    1.0       5511.0       14.0
# Bond MTR Reconsider                            0.0          1.0        0.0
# Bond MTR Reinstate                             0.0          3.0        0.0
# Bond MTR Reopen                                0.0          0.0        0.0
# Case Appeal                                  101.0     140490.0    27977.0
# Circuit Court Remand                           0.0       1170.0      208.0
# Interlocutory Appeal                           0.0        633.0      297.0
# MTR BIA                                        4.0      40877.0     7473.0
# Reasonable Cause Appeal                        0.0          0.0        0.0
# Special Circumstances Appeal                   0.0          0.0        0.0
# Zero Bond Appeal                               0.0          4.0        0.0
#
# case_type_string              NACARA ADJUSTMENT  NOT_MATCHED_TO_MASTER  \
# strAppealTypeDesc
# Appeal of IJ MTR                            4.0                  358.0
# Bond Appeal                                 0.0                 1589.0
# Bond MTR Reconsider                         0.0                   11.0
# Bond MTR Reinstate                          0.0                    1.0
# Bond MTR Reopen                             0.0                    2.0
# Case Appeal                                56.0                 9157.0
# Circuit Court Remand                        0.0                   55.0
# Interlocutory Appeal                        0.0                  328.0
# MTR BIA                                     8.0                 1427.0
# Reasonable Cause Appeal                     0.0                    0.0
# Special Circumstances Appeal                0.0                    0.0
# Zero Bond Appeal                            0.0                    1.0
#
# case_type_string              REASONABLE FEAR CASE  RECISSION   REMOVAL  \
# strAppealTypeDesc
# Appeal of IJ MTR                               0.0        6.0   21347.0
# Bond Appeal                                    1.0        0.0   15259.0
# Bond MTR Reconsider                            0.0        0.0      84.0
# Bond MTR Reinstate                             0.0        0.0      25.0
# Bond MTR Reopen                                0.0        0.0      46.0
# Case Appeal                                   87.0      380.0  322863.0
# Circuit Court Remand                           0.0        0.0   11134.0
# Interlocutory Appeal                           2.0        5.0    2101.0
# MTR BIA                                        5.0       24.0  104105.0
# Reasonable Cause Appeal                        0.0        0.0       0.0
# Special Circumstances Appeal                   0.0        0.0       0.0
# Zero Bond Appeal                               0.0        0.0       0.0
#
# case_type_string              WITHHOLDING ONLY
# strAppealTypeDesc
# Appeal of IJ MTR                          12.0
# Bond Appeal                                6.0
# Bond MTR Reconsider                        0.0
# Bond MTR Reinstate                         0.0
# Bond MTR Reopen                            0.0
# Case Appeal                              974.0
# Circuit Court Remand                      27.0
# Interlocutory Appeal                       9.0
# MTR BIA                                   93.0
# Reasonable Cause Appeal                    0.0
# Special Circumstances Appeal               0.0
# Zero Bond Appeal                           0.0

# %%
# distribution of appeal vs. proceeding types - what dunn included 
appeals_in_scope[appeals_in_scope['in_dunn'] == 1].groupby(['strAppealTypeDesc', 'case_type_string']).size().unstack().fillna(0)
# Out:
# case_type_string           ASYLUM ONLY CASE  DEPORTATION  EXCLUSION   REMOVAL  \
# strAppealTypeDesc
# Appeal of IJ MTR      0.0              93.0       2653.0      478.0    3026.0
# Bond Appeal           0.0              10.0        569.0        7.0    2388.0
# Bond MTR Reconsider   0.0               0.0          0.0        0.0      12.0
# Bond MTR Reinstate    0.0               0.0          0.0        0.0       4.0
# Bond MTR Reopen       0.0               0.0          0.0        0.0      10.0
# Case Appeal           2.0            3878.0      66912.0    18341.0  173865.0
# Circuit Court Remand  0.0             186.0        604.0      145.0    7058.0
# Interlocutory Appeal  1.0               7.0         68.0       41.0     486.0
# MTR BIA               0.0            1231.0      21833.0     5739.0   59309.0
#
# case_type_string      WITHHOLDING ONLY
# strAppealTypeDesc
# Appeal of IJ MTR                   9.0
# Bond Appeal                        6.0
# Bond MTR Reconsider                0.0
# Bond MTR Reinstate                 0.0
# Bond MTR Reopen                    0.0
# Case Appeal                      842.0
# Circuit Court Remand              26.0
# Interlocutory Appeal               7.0
# MTR BIA                           87.0

# %% [markdown]
# #### Final Criteria: appeal types in ['Appeal of IJ MTR', 'Case Appeal', 'Circuit Court Remand', 'Interlocutory Appeal', 'MTR BIA'] and is found in Dunn's

# %%
# filter relevant appeal types 
selected_appeal_types = ['Appeal of IJ MTR', 'Case Appeal', 'Circuit Court Remand', 'Interlocutory Appeal', 'MTR BIA'] 
appeals_in_scope = appeals_in_scope[appeals_in_scope['strAppealTypeDesc'].isin(selected_appeal_types) & 
                                    appeals_in_scope['in_dunn'] == 1].copy() 
appeals_in_scope.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 366927 entries, 3 to 740756
# Data columns (total 28 columns):
# idnAppeal                 366927 non-null int64
# idncase                   366927 non-null int64
# idnProceeding             366927 non-null int64
# strAppealCategory         366927 non-null object
# strAppealType             366927 non-null object
# datAppealFiled            366863 non-null object
# strFiledBy                366918 non-null object
# datAttorneyE27            255225 non-null object
# datBIADecision            366927 non-null object
# strBIADecision            366927 non-null object
# strBIADecisionType        356952 non-null object
# strCaseType               366926 non-null object
# strLang                   366119 non-null object
# strNat                    366752 non-null object
# strProceedingIHP          183004 non-null object
# strCustody                309504 non-null object
# strProbono                750 non-null object
# datAppealFiled_dt         366863 non-null datetime64[ns]
# datBIADecision_dt         366927 non-null datetime64[ns]
# datAppealFiled_year       366863 non-null float64
# strAppealCategoryDesc     366457 non-null object
# strAppealTypeDesc         366927 non-null object
# strBIADecisionDesc        366927 non-null object
# strBIADecisionTypeDesc    356670 non-null object
# idnproceeding_x           366927 non-null float64
# in_dunn                   366927 non-null float64
# idnproceeding_y           366927 non-null float64
# case_type_string          366927 non-null object
# dtypes: datetime64[ns](2), float64(4), int64(3), object(19)
# memory usage: 81.2+ MB

# %% [markdown]
# # Assign Labels

# %%
# many different labels 
appeals_in_scope.groupby(['strBIADecisionDesc', 'strAppealTypeDesc']).size().unstack().fillna(0)
# Out:
# strAppealTypeDesc                            Appeal of IJ MTR  Case Appeal  \
# strBIADecisionDesc
# Administrative Return                                     0.0         11.0
# Background Check Remand                                  17.0       4367.0
# Continued                                                 2.0       1191.0
# Denied                                                    4.0         24.0
# Dismiss Appeal/Affirm IJ's Decision                    3304.0      96072.0
# Dismiss as Untimely                                     102.0       1761.0
# Dismissed (Grant V/D 30 days)                             3.0      30534.0
# Dismissed (Voluntary Departure Granted)                  24.0      11259.0
# Grant With No Remand                                      0.0          0.0
# Granted                                                   0.0         27.0
# Lacks Jurisdiction  - BIA                               211.0       3327.0
# Other                                                   110.0       2915.0
# Other Soriano                                             0.0          3.0
# Rejection                                                12.0        333.0
# Remand                                                 1290.0      32200.0
# SUMMARY AFFIRMANCE/VD                                    12.0      10908.0
# Summary Affirmance                                      783.0      35857.0
# Summary Dismiss                                          73.0       5968.0
# Summary Dismissal (O) Other                               0.0         15.0
# Summary Dismissal (a) inad reason on appeal               7.0        274.0
# Summary Dismissal (e) no brief                           17.0        603.0
# Summary Dismissal - Both (a) & (e)                        9.0        436.0
# Sustain                                                  22.0       6791.0
# Temporary Protected Status                               26.0      11686.0
# Termination                                              21.0        363.0
# Withdrawl of Appeal                                     210.0       6915.0
#
# strAppealTypeDesc                            Circuit Court Remand  \
# strBIADecisionDesc
# Administrative Return                                         0.0
# Background Check Remand                                     588.0
# Continued                                                    23.0
# Denied                                                       29.0
# Dismiss Appeal/Affirm IJ's Decision                         770.0
# Dismiss as Untimely                                           0.0
# Dismissed (Grant V/D 30 days)                                 1.0
# Dismissed (Voluntary Departure Granted)                     198.0
# Grant With No Remand                                          0.0
# Granted                                                       3.0
# Lacks Jurisdiction  - BIA                                     7.0
# Other                                                       511.0
# Other Soriano                                                 0.0
# Rejection                                                     0.0
# Remand                                                     5692.0
# SUMMARY AFFIRMANCE/VD                                         5.0
# Summary Affirmance                                            0.0
# Summary Dismiss                                               0.0
# Summary Dismissal (O) Other                                   0.0
# Summary Dismissal (a) inad reason on appeal                   0.0
# Summary Dismissal (e) no brief                                0.0
# Summary Dismissal - Both (a) & (e)                            0.0
# Sustain                                                      59.0
# Temporary Protected Status                                    4.0
# Termination                                                 115.0
# Withdrawl of Appeal                                          14.0
#
# strAppealTypeDesc                            Interlocutory Appeal  MTR BIA
# strBIADecisionDesc
# Administrative Return                                         0.0     10.0
# Background Check Remand                                       0.0    117.0
# Continued                                                     0.0     23.0
# Denied                                                        0.0  55687.0
# Dismiss Appeal/Affirm IJ's Decision                         209.0     16.0
# Dismiss as Untimely                                           1.0     28.0
# Dismissed (Grant V/D 30 days)                                 2.0     19.0
# Dismissed (Voluntary Departure Granted)                       0.0      0.0
# Grant With No Remand                                          0.0    983.0
# Granted                                                       0.0   9975.0
# Lacks Jurisdiction  - BIA                                     7.0   1018.0
# Other                                                       328.0   3550.0
# Other Soriano                                                 1.0      5.0
# Rejection                                                     2.0    133.0
# Remand                                                       14.0   9635.0
# SUMMARY AFFIRMANCE/VD                                         0.0    107.0
# Summary Affirmance                                            0.0    224.0
# Summary Dismiss                                               0.0     18.0
# Summary Dismissal (O) Other                                   0.0      1.0
# Summary Dismissal (a) inad reason on appeal                   0.0      0.0
# Summary Dismissal (e) no brief                                0.0      1.0
# Summary Dismissal - Both (a) & (e)                            0.0      1.0
# Sustain                                                       3.0      1.0
# Temporary Protected Status                                    0.0    143.0
# Termination                                                   0.0   5404.0
# Withdrawl of Appeal                                          43.0   1100.0

# %%
# assign positive and negative labels
granted_decisions = ['Background Check Remand', 'Grant With No Remand', 'Granted', 'Remand', 
                     'Sustain', 'Temporary Protected Status']
denied_decisions = ['Denied', "Dismiss Appeal/Affirm IJ's Decision", 'Dismissed (Grant V/D 30 days)', 
                    'Dismissed (Voluntary Departure Granted)', 'Rejection', 'SUMMARY AFFIRMANCE/VD', 
                    'Summary Affirmance', 'Summary Dismiss', 'Summary Dismissal (O) Other', 
                    'Summary Dismissal (a) inad reason on appeal', 'Summary Dismissal - Both (a) & (e)']
appeals_in_scope['granted'] = np.where(appeals_in_scope['strBIADecisionDesc'].isin(granted_decisions), 1, 
                                       np.where(appeals_in_scope['strBIADecisionDesc'].isin(denied_decisions), 0, None))

# drop neutral labels where appeals were dismissed due to administrative/procedural failures 
appeals_in_scope.dropna(subset=['granted'], inplace=True)
appeals_in_scope['granted'] = appeals_in_scope['granted'].astype(int)
appeals_in_scope.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336976 entries, 3 to 740753
# Data columns (total 29 columns):
# idnAppeal                 336976 non-null int64
# idncase                   336976 non-null int64
# idnProceeding             336976 non-null int64
# strAppealCategory         336976 non-null object
# strAppealType             336976 non-null object
# datAppealFiled            336916 non-null object
# strFiledBy                336967 non-null object
# datAttorneyE27            237308 non-null object
# datBIADecision            336976 non-null object
# strBIADecision            336976 non-null object
# strBIADecisionType        329045 non-null object
# strCaseType               336975 non-null object
# strLang                   336254 non-null object
# strNat                    336825 non-null object
# strProceedingIHP          166763 non-null object
# strCustody                285583 non-null object
# strProbono                691 non-null object
# datAppealFiled_dt         336916 non-null datetime64[ns]
# datBIADecision_dt         336976 non-null datetime64[ns]
# datAppealFiled_year       336916 non-null float64
# strAppealCategoryDesc     336622 non-null object
# strAppealTypeDesc         336976 non-null object
# strBIADecisionDesc        336976 non-null object
# strBIADecisionTypeDesc    328778 non-null object
# idnproceeding_x           336976 non-null float64
# in_dunn                   336976 non-null float64
# idnproceeding_y           336976 non-null float64
# case_type_string          336976 non-null object
# granted                   336976 non-null int64
# dtypes: datetime64[ns](2), float64(4), int64(4), object(19)
# memory usage: 77.1+ MB

# %% [markdown]
# # Dedup for unique (idncase, idnproceeding)

# %% [markdown]
# ~24% of remaining proceedings have multiple appeals

# %%
appeals_per_proceeding = appeals_in_scope.groupby(['idnProceeding'])['idnAppeal'].nunique()
appeals_per_proceeding.value_counts(normalize=True)
# Out:
# 1     0.756449
# 2     0.184694
# 3     0.042579
# 4     0.011327
# 5     0.003151
# 6     0.001162
# 7     0.000351
# 8     0.000106
# 9     0.000051
# 15    0.000043
# 10    0.000024
# 13    0.000020
# 11    0.000016
# 12    0.000008
# 20    0.000008
# 21    0.000004
# 14    0.000004
# 23    0.000004
# Name: idnAppeal, dtype: float64

# %% [markdown]
# Most multiple appeals seem to involve 'MTR' after initial 'Case Appeal'. Should we use the last instance of 'MTR' as the final decision?

# %%
# examples of proceedings with multiple appeals 
sample_index = random.sample(appeals_per_proceeding[appeals_per_proceeding > 1].index, 1)
tblAppeal_df[tblAppeal_df['idnProceeding'].isin(sample_index)].T
# Out:
#                                                         306207  \
# idnAppeal                                              4504808
# idncase                                                4084134
# idnProceeding                                          2555620
# strAppealCategory                                           IJ
# strAppealType                                      Case Appeal
# datAppealFiled                             2001-10-03 00:00:00
# strFiledBy                                                   A
# datAttorneyE27                             2001-10-03 00:00:00
# datBIADecision                             2002-12-11 00:00:00
# strBIADecision                                             SAF
# strBIADecisionType                                         NaN
# strCaseType                                                RMV
# strLang                                                     SP
# strNat                                                      CO
# strProceedingIHP
# strCustody                                                   N
# strProbono                                                 NaN
# datAppealFiled_dt                          2001-10-03 00:00:00
# datBIADecision_dt                          2002-12-11 00:00:00
# datAppealFiled_year                                       2001
# strAppealCategoryDesc   Appeal from Immigration Judge decision
# strAppealTypeDesc                                  Case Appeal
# strBIADecisionDesc                          Summary Affirmance
# strBIADecisionTypeDesc                                     NaN
#
#                                                         363526
# idnAppeal                                              4567207
# idncase                                                4084134
# idnProceeding                                          2555620
# strAppealCategory                                           IJ
# strAppealType                                          MTR BIA
# datAppealFiled                             2003-02-19 00:00:00
# strFiledBy                                                   A
# datAttorneyE27                             2003-08-22 00:00:00
# datBIADecision                             2003-09-23 00:00:00
# strBIADecision                                             DEN
# strBIADecisionType                                           P
# strCaseType                                                RMV
# strLang                                                     SP
# strNat                                                      CO
# strProceedingIHP
# strCustody                                                   N
# strProbono                                                 NaN
# datAppealFiled_dt                          2003-02-19 00:00:00
# datBIADecision_dt                          2003-09-23 00:00:00
# datAppealFiled_year                                       2003
# strAppealCategoryDesc   Appeal from Immigration Judge decision
# strAppealTypeDesc                                      MTR BIA
# strBIADecisionDesc                                      Denied
# strBIADecisionTypeDesc                          Percuriam Case

# %%
# check original proceedings for a given case 
master_dchen_df[master_dchen_df['idncase'] == 2241734].T
# Out:
#                                                     4812094
# idncase                                             2241734
# nat                                                      EG
# case_type                                               DEP
# c_asy_type                                                E
# idnproceeding                                        361062
# base_city_code                                          NEW
# hearing_loc_code                                        NEW
# dec_type                                                  O
# dec_code                                                  V
# other_comp
# attorney_flag                                             1
# ij_code                                                 NWG
# tracid                                                  241
# comp_year                                              1986
# comp_month                                                8
# comp_day                                                 13
# comp_date                                              9721
# osc_year                                               1985
# osc_month                                                 9
# osc_day                                                  23
# osc_date                                               9397
# input_year                                             1985
# input_month                                               9
# input_day                                                25
# input_date                                             9399
# lawyer                                                    1
# defensive                                                 1
# affirmative                                               0
# case_type_string                                DEPORTATION
# _mcase                                          matched (3)
# dec_type_string                               ORAL DECISION
# _mdectype                                       matched (3)
# outcome_recorded_in_field                                 C
# dec_string                              VOLUNTARY DEPARTURE
# _mdecproceeddec                                 matched (3)
# _mdecproceedoth                             master only (1)
# nat_string                                            EGYPT
# _mnat                                           matched (3)
# base_city_street                970 BROAD STREET, ROOM 1200
# base_city_string                                     NEWARK
# base_city_state                                          NJ
# base_city_zip5                                         7102
# base_city_zip4                                            0
# base_city_phone                                 9.73645e+09
# _mbasecity                                      matched (3)
# hearing_loc_string1                      NEWARK, NEW JERSEY
# hearing_loc_string2                       IMMIGRATION COURT
# hearing_loc_street              970 BROAD STREET, ROOM 1200
# hearing_loc_city                                     NEWARK
# hearing_loc_state                                        NJ
# hearing_loc_zip5                                       7102
# hearing_loc_phone                                2016453524
# _mhearingloc                                    matched (3)
# judge_name_caps                            NATHAN W. GORDON
# _mlookupijcode                                  matched (3)
# cityid                                                   32
# judgeid                                                 289
# natid                                                    67
# venue_change                                              0
# deport                                                    0
# relief_granted                                            0
# remove                                                    0
# terminated                                                0
# voluntary_departure                                       1
# oral                                                      1
# written                                                   0
# deport_form                                               0
# voluntary_form                                            0
# deportation_proceeding                                    1
# exclusion_proceeding                                      0
# removal_proceeding                                        0
# asylum_only_proceeding                                    0
# withholding_only_proceeding                               0
# idncode                                              345593
# strdescription_chicago                               ASYLUM
# flag_decisionerror_strdes                                 0
# decision1_chicago                                      DENY
# grantordeny_chicago                                       1
# flag_decisionerror_idncaseproc                            1
# decision2_chicago                                      DENY
# grant_asylum_chicago                                      0
# grant_withhold_chicago                                  NaN
# grant_cat_chicago                                       NaN
# _mmasterappl                                    matched (3)
# strdescription_holger
# decision1_holger
# grantordeny_holger                                      NaN
# decision2_holger
# grant_asylum_holger                                     NaN
# grant_withhold_holger                                   NaN
# grant_cat_holger                                        NaN
# _mmasterappl2                               master only (1)
# adj_hearing_loc_code                                    NEW
# adj_base_city_code                                      NEW
# adj_time_start                                          900
# adj_date                                               9721
# adj_input_date                                        17326
# adj_osc_date                                           9397
# flag_earlystarttime                                       0
# eoirattyid                                            60932
# alienattyid                                           16573
# _mschedcompdate                             master only (1)
# flag_mismatch_base_city                                   0
# flag_mismatch_hearing                                     0
# _mscheddatetime                         missing updated (4)
# flag_datemismatch                                         0
# dec_col                                                   C
# dec_judge                                                 V
# dec_type_str                                  oral decision
# case_type_str                                   Deportation
# dec_code_str                            Voluntary Departure

# %% [markdown]
# ~2% of cases have multiple proceedings

# %%
proceedings_per_case = appeals_in_scope.groupby(['idncase'])['idnProceeding'].nunique()
proceedings_per_case.value_counts(normalize=True)
# Out:
# 1    0.978357
# 2    0.020922
# 3    0.000713
# 4    0.000008
# Name: idnProceeding, dtype: float64

# %%
# examples of cases with multiple proceedings 
sample_index = random.sample(proceedings_per_case[proceedings_per_case > 1].index, 1)
appeals_in_scope[appeals_in_scope['idncase'].isin(sample_index)].sort_values(by='datAppealFiled_dt').T
# Out:
#                                                         164312  \
# idnAppeal                                              4348577
# idncase                                                2962678
# idnProceeding                                          1291597
# strAppealCategory                                           IJ
# strAppealType                                      Case Appeal
# datAppealFiled                             1997-05-28 00:00:00
# strFiledBy                                                   A
# datAttorneyE27                             2000-04-24 00:00:00
# datBIADecision                             2000-06-22 00:00:00
# strBIADecision                                             REM
# strBIADecisionType                                           R
# strCaseType                                                DEP
# strLang                                                    PUN
# strNat                                                      IN
# strProceedingIHP
# strCustody                                                 NaN
# strProbono                                                 NaN
# datAppealFiled_dt                          1997-05-28 00:00:00
# datBIADecision_dt                          2000-06-22 00:00:00
# datAppealFiled_year                                       1997
# strAppealCategoryDesc   Appeal from Immigration Judge decision
# strAppealTypeDesc                                  Case Appeal
# strBIADecisionDesc                                      Remand
# strBIADecisionTypeDesc                            Regular Case
# idnproceeding_x                                     1.2916e+06
# in_dunn                                                      1
# idnproceeding_y                                     1.2916e+06
# case_type_string                                   DEPORTATION
# granted                                                      1
#
#                                                         278591
# idnAppeal                                              4486150
# idncase                                                2962678
# idnProceeding                                          1291596
# strAppealCategory                                           IJ
# strAppealType                                      Case Appeal
# datAppealFiled                             2001-03-26 00:00:00
# strFiledBy                                                   A
# datAttorneyE27                             2001-03-26 00:00:00
# datBIADecision                             2003-11-17 00:00:00
# strBIADecision                                             DIS
# strBIADecisionType                                           R
# strCaseType                                                DEP
# strLang                                                    PUN
# strNat                                                      IN
# strProceedingIHP
# strCustody                                                   N
# strProbono                                                 NaN
# datAppealFiled_dt                          2001-03-26 00:00:00
# datBIADecision_dt                          2003-11-17 00:00:00
# datAppealFiled_year                                       2001
# strAppealCategoryDesc   Appeal from Immigration Judge decision
# strAppealTypeDesc                                  Case Appeal
# strBIADecisionDesc         Dismiss Appeal/Affirm IJ's Decision
# strBIADecisionTypeDesc                            Regular Case
# idnproceeding_x                                     1.2916e+06
# in_dunn                                                      1
# idnproceeding_y                                     1.2916e+06
# case_type_string                                   DEPORTATION
# granted                                                      0

# %%
# check original proceedings for a given case 
master_df[master_df['idncase'] == 5612569].T
# Out:
#                       4112806          4112807        4112808  \
# idncase           5.61257e+06      5.61257e+06    5.61257e+06
# nat                        ZA               ZA             ZA
# case_type                 RMV              RMV            RMV
# c_asy_type                NaN              NaN            NaN
# idnproceeding         4054290          4066075        4093297
# base_city_code            FLO              PHO            ATL
# hearing_loc_code          FLO              PHO            ATL
# dec_type                  NaN              NaN              O
# dec_code                  NaN              NaN              X
# other_comp                  T                C            NaN
# osc_date            02OCT2006        02OCT2006      02OCT2006
# input_date          05OCT2006        23OCT2006      28NOV2006
# comp_date           23OCT2006        27NOV2006      11JAN2007
# attorney_flag               1                1              1
# ij_code                   SMJ              WAH            JDP
# tracid                     56              176            287
# dec_col                     O                O              C
# dec_judge                   T                C              X
# dec_type_str              NaN              NaN  oral decision
# case_type_str         Removal          Removal        Removal
# dec_code_str         Transfer  Change of Venue         Remove
#
#                                           4112809        4112810
# idncase                               5.61257e+06    5.61257e+06
# nat                                            ZA             ZA
# case_type                                     RMV            RMV
# c_asy_type                                    NaN            NaN
# idnproceeding                             4370491        5116381
# base_city_code                                ATL            ATL
# hearing_loc_code                              ATL            ATL
# dec_type                                      NaN              O
# dec_code                                      NaN              T
# other_comp                                      O            NaN
# osc_date                                02OCT2006      02OCT2006
# input_date                              08NOV2007      12MAR2010
# comp_date                               14OCT2008      01NOV2012
# attorney_flag                                   1              1
# ij_code                                       NaN            JDP
# tracid                                        NaN            287
# dec_col                                         O              C
# dec_judge                                       O              T
# dec_type_str                                  NaN  oral decision
# case_type_str                             Removal        Removal
# dec_code_str      Other Administrative Completion     Terminated

# %% [markdown]
# ** For each unique (case,proceeding) pairs with more than 1 appeal, pick the last appeal and dedup the rest **

# %%
appeals_deduped = appeals_in_scope.sort_values(by=['idncase', 'idnProceeding', 'datBIADecision_dt'], 
                                               ascending=[True, True, False])
appeals_deduped.drop_duplicates(subset=['idncase', 'idnProceeding'], keep='first', inplace=True)
appeals_deduped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 253906 entries, 433199 to 731825
# Data columns (total 29 columns):
# idnAppeal                 253906 non-null int64
# idncase                   253906 non-null int64
# idnProceeding             253906 non-null int64
# strAppealCategory         253906 non-null object
# strAppealType             253906 non-null object
# datAppealFiled            253850 non-null object
# strFiledBy                253901 non-null object
# datAttorneyE27            178834 non-null object
# datBIADecision            253906 non-null object
# strBIADecision            253906 non-null object
# strBIADecisionType        247517 non-null object
# strCaseType               253906 non-null object
# strLang                   253572 non-null object
# strNat                    253789 non-null object
# strProceedingIHP          123803 non-null object
# strCustody                212262 non-null object
# strProbono                578 non-null object
# datAppealFiled_dt         253850 non-null datetime64[ns]
# datBIADecision_dt         253906 non-null datetime64[ns]
# datAppealFiled_year       253850 non-null float64
# strAppealCategoryDesc     253667 non-null object
# strAppealTypeDesc         253906 non-null object
# strBIADecisionDesc        253906 non-null object
# strBIADecisionTypeDesc    247323 non-null object
# idnproceeding_x           253906 non-null float64
# in_dunn                   253906 non-null float64
# idnproceeding_y           253906 non-null float64
# case_type_string          253906 non-null object
# granted                   253906 non-null int64
# dtypes: datetime64[ns](2), float64(4), int64(4), object(19)
# memory usage: 58.1+ MB

# %% [markdown]
# **31% of appeals were granted**

# %%
# check % granted in final dataset 
appeals_deduped['granted'].value_counts()
# Out:
# 0    175095
# 1     78811
# Name: granted, dtype: int64

# %% [markdown]
# # Merge Datasets

# %% [markdown]
# #### Add variables from master-chen

# %%
# variables in processed data by Prof. Chen
print(master_dchen.columns.tolist())
# Out:
# ['idncase', 'nat', 'case_type', 'c_asy_type', 'idnproceeding', 'base_city_code', 'hearing_loc_code', 'dec_type', 'dec_code', 'other_comp', 'attorney_flag', 'ij_code', 'tracid', 'comp_year', 'comp_month', 'comp_day', 'comp_date', 'osc_year', 'osc_month', 'osc_day', 'osc_date', 'input_year', 'input_month', 'input_day', 'input_date', 'lawyer', 'defensive', 'affirmative', 'case_type_string', '_mcase', 'dec_type_string', '_mdectype', 'outcome_recorded_in_field', 'dec_string', '_mdecproceeddec', '_mdecproceedoth', 'nat_string', '_mnat', 'base_city_street', 'base_city_string', 'base_city_state', 'base_city_zip5', 'base_city_zip4', 'base_city_phone', '_mbasecity', 'hearing_loc_string1', 'hearing_loc_string2', 'hearing_loc_street', 'hearing_loc_city', 'hearing_loc_state', 'hearing_loc_zip5', 'hearing_loc_phone', '_mhearingloc', 'judge_name_caps', '_mlookupijcode', 'cityid', 'judgeid', 'natid', 'venue_change', 'deport', 'relief_granted', 'remove', 'terminated', 'voluntary_departure', 'oral', 'written', 'deport_form', 'voluntary_form', 'deportation_proceeding', 'exclusion_proceeding', 'removal_proceeding', 'asylum_only_proceeding', 'withholding_only_proceeding', 'idncode', 'strdescription_chicago', 'flag_decisionerror_strdes', 'decision1_chicago', 'grantordeny_chicago', 'flag_decisionerror_idncaseproc', 'decision2_chicago', 'grant_asylum_chicago', 'grant_withhold_chicago', 'grant_cat_chicago', '_mmasterappl', 'strdescription_holger', 'decision1_holger', 'grantordeny_holger', 'decision2_holger', 'grant_asylum_holger', 'grant_withhold_holger', 'grant_cat_holger', '_mmasterappl2', 'adj_hearing_loc_code', 'adj_base_city_code', 'adj_time_start', 'adj_date', 'adj_input_date', 'adj_osc_date', 'flag_earlystarttime', 'eoirattyid', 'alienattyid', '_mschedcompdate', 'flag_mismatch_base_city', 'flag_mismatch_hearing', '_mscheddatetime', 'flag_datemismatch', 'dec_col', 'dec_judge']

# %%
master_dchen.groupby(['grantordeny_chicago']).size()
# Out:
# grantordeny_chicago
# 1.0    609491
# dtype: int64

# %%
master_dchen.isnull().sum()
# Out:
# idncase                                 0
# nat                                     0
# case_type                               0
# c_asy_type                              0
# idnproceeding                           0
# base_city_code                          0
# hearing_loc_code                        0
# dec_type                                0
# dec_code                                0
# other_comp                              0
# attorney_flag                     2907462
# ij_code                                 0
# tracid                             248615
# comp_year                               0
# comp_month                              0
# comp_day                                0
# comp_date                               0
# osc_year                            32420
# osc_month                           32420
# osc_day                             32420
# osc_date                            32420
# input_year                          27549
# input_month                         27549
# input_day                           27549
# input_date                          27549
# lawyer                                  0
# defensive                         4156705
# affirmative                       4156705
# case_type_string                        0
# _mcase                                  0
# dec_type_string                         0
# _mdectype                               0
# outcome_recorded_in_field               0
# dec_string                              0
# _mdecproceeddec                         0
# _mdecproceedoth                         0
# nat_string                              0
# _mnat                                   0
# base_city_street                        0
# base_city_string                        0
# base_city_state                         0
# base_city_zip5                          0
# base_city_zip4                     429285
# base_city_phone                         0
# _mbasecity                              0
# hearing_loc_string1                     0
# hearing_loc_string2                     0
# hearing_loc_street                      0
# hearing_loc_city                        0
# hearing_loc_state                       0
# hearing_loc_zip5                     2801
# hearing_loc_phone                       0
# _mhearingloc                            0
# judge_name_caps                         0
# _mlookupijcode                          0
# cityid                                  0
# judgeid                                 0
# natid                               27544
# venue_change                          332
# deport                                332
# relief_granted                        332
# remove                                332
# terminated                            332
# voluntary_departure                   332
# oral                              1150629
# written                           1150629
# deport_form                       1150629
# voluntary_form                    1150629
# deportation_proceeding                112
# exclusion_proceeding                  112
# removal_proceeding                    112
# asylum_only_proceeding                112
# withholding_only_proceeding           112
# idncode                                 0
# strdescription_chicago                  0
# flag_decisionerror_strdes         4451881
# decision1_chicago                       0
# grantordeny_chicago               5055262
# flag_decisionerror_idncaseproc    4451881
# decision2_chicago                       0
# grant_asylum_chicago              5095875
# grant_withhold_chicago            5281083
# grant_cat_chicago                 5469762
# _mmasterappl                            0
# strdescription_holger                   0
# decision1_holger                        0
# grantordeny_holger                5207993
# decision2_holger                        0
# grant_asylum_holger               5230454
# grant_withhold_holger             5355571
# grant_cat_holger                  5498503
# _mmasterappl2                           0
# adj_hearing_loc_code                    0
# adj_base_city_code                      0
# adj_time_start                      73671
# adj_date                            72842
# adj_input_date                      72842
# adj_osc_date                        82823
# flag_earlystarttime                 72842
# eoirattyid                        3460334
# alienattyid                       3390990
# _mschedcompdate                         0
# flag_mismatch_base_city             72842
# flag_mismatch_hearing               73922
# _mscheddatetime                   4781556
# flag_datemismatch                 4781556
# dec_col                                 0
# dec_judge                               0
# dtype: int64

# %%
master_dchen.sample(4).T
# Out:
#                                                 1825326  \
# idncase                                         3669309
# nat                                                  CH
# case_type                                           RMV
# c_asy_type                                            I
# idnproceeding                                   2020253
# base_city_code                                      LOS
# hearing_loc_code                                    LOS
# dec_type                                              O
# dec_code                                              R
# other_comp
# attorney_flag                                         1
# ij_code                                              HO
# tracid                                               94
# comp_year                                          2004
# comp_month                                           11
# comp_day                                             19
# comp_date                                         16394
# osc_year                                           1999
# osc_month                                             8
# osc_day                                               2
# osc_date                                          14458
# input_year                                         1999
# input_month                                           8
# input_day                                            23
# input_date                                        14479
# lawyer                                                1
# defensive                                             0
# affirmative                                           1
# case_type_string                                REMOVAL
# _mcase                                      matched (3)
# dec_type_string                           ORAL DECISION
# _mdectype                                   matched (3)
# outcome_recorded_in_field                             C
# dec_string                               RELIEF GRANTED
# _mdecproceeddec                             matched (3)
# _mdecproceedoth                         master only (1)
# nat_string                                        CHINA
# _mnat                                       matched (3)
# base_city_street                    606 SOUTH OLIVE ST.
# base_city_string                            LOS ANGELES
# base_city_state                                      CA
# base_city_zip5                                    90014
# base_city_zip4                                        0
# base_city_phone                             2.13894e+09
# _mbasecity                                  matched (3)
# hearing_loc_string1             LOS ANGELES, CALIFORNIA
# hearing_loc_string2                   IMMIGRATION COURT
# hearing_loc_street                  606 SOUTH OLIVE ST.
# hearing_loc_city                            LOS ANGELES
# hearing_loc_state                                    CA
# hearing_loc_zip5                                  90014
# hearing_loc_phone                            2138942811
# _mhearingloc                                matched (3)
# judge_name_caps                                 ANNA HO
# _mlookupijcode                              matched (3)
# cityid                                               28
# judgeid                                             152
# natid                                                44
# venue_change                                          0
# deport                                                0
# relief_granted                                        1
# remove                                                0
# terminated                                            0
# voluntary_departure                                   0
# oral                                                  1
# written                                               0
# deport_form                                           0
# voluntary_form                                        0
# deportation_proceeding                                0
# exclusion_proceeding                                  0
# removal_proceeding                                    1
# asylum_only_proceeding                                0
# withholding_only_proceeding                           0
# idncode                                     1.98207e+06
# strdescription_chicago                           ASYLUM
# flag_decisionerror_strdes                             1
# decision1_chicago                                 GRANT
# grantordeny_chicago                                   1
# flag_decisionerror_idncaseproc                        1
# decision2_chicago                                 GRANT
# grant_asylum_chicago                                  1
# grant_withhold_chicago                              NaN
# grant_cat_chicago                                   NaN
# _mmasterappl                                matched (3)
# strdescription_holger                            ASYLUM
# decision1_holger                                  GRANT
# grantordeny_holger                                    1
# decision2_holger                                  GRANT
# grant_asylum_holger                                   1
# grant_withhold_holger                               NaN
# grant_cat_holger                                    NaN
# _mmasterappl2                               matched (3)
# adj_hearing_loc_code                                LOS
# adj_base_city_code                                  LOS
# adj_time_start                                     1300
# adj_date                                          16394
# adj_input_date                                    17242
# adj_osc_date                                      14458
# flag_earlystarttime                                   0
# eoirattyid                                         1000
# alienattyid                                        3662
# _mschedcompdate                             matched (3)
# flag_mismatch_base_city                               0
# flag_mismatch_hearing                                 0
# _mscheddatetime                                     NaN
# flag_datemismatch                                   NaN
# dec_col                                               C
# dec_judge                                             R
#
#                                                        1887523  \
# idncase                                                3721250
# nat                                                         CH
# case_type                                                  RMV
# c_asy_type                                                   I
# idnproceeding                                          2083270
# base_city_code                                             NYC
# hearing_loc_code                                           NYX
# dec_type                                                     O
# dec_code                                                     X
# other_comp
# attorney_flag                                                1
# ij_code                                                    ERK
# tracid                                                     212
# comp_year                                                 1999
# comp_month                                                   8
# comp_day                                                     2
# comp_date                                                14458
# osc_year                                                  1998
# osc_month                                                   10
# osc_day                                                      6
# osc_date                                                 14158
# input_year                                                1998
# input_month                                                 10
# input_day                                                   23
# input_date                                               14175
# lawyer                                                       1
# defensive                                                    0
# affirmative                                                  1
# case_type_string                                       REMOVAL
# _mcase                                             matched (3)
# dec_type_string                                  ORAL DECISION
# _mdectype                                          matched (3)
# outcome_recorded_in_field                                    C
# dec_string                                              REMOVE
# _mdecproceeddec                                    matched (3)
# _mdecproceedoth                                master only (1)
# nat_string                                               CHINA
# _mnat                                              matched (3)
# base_city_street                26 FEDERAL PLZ 12TH FL RM 1237
# base_city_string                                      NEW YORK
# base_city_state                                             NY
# base_city_zip5                                           10278
# base_city_zip4                                               0
# base_city_phone                                    2.12265e+09
# _mbasecity                                         matched (3)
# hearing_loc_string1                             NEW YORK ANNEX
# hearing_loc_string2                          IMMIGRATION COURT
# hearing_loc_street                 26 FEDERAL PLAZA, ROOM 1237
# hearing_loc_city                                      NEW YORK
# hearing_loc_state                                           NY
# hearing_loc_zip5                                         10278
# hearing_loc_phone                                   2126204772
# _mhearingloc                                       matched (3)
# judge_name_caps                              EDWARD R. KANDLER
# _mlookupijcode                                     matched (3)
# cityid                                                      34
# judgeid                                                    113
# natid                                                       44
# venue_change                                                 0
# deport                                                       0
# relief_granted                                               0
# remove                                                       1
# terminated                                                   0
# voluntary_departure                                          0
# oral                                                         1
# written                                                      0
# deport_form                                                  0
# voluntary_form                                               0
# deportation_proceeding                                       0
# exclusion_proceeding                                         0
# removal_proceeding                                           1
# asylum_only_proceeding                                       0
# withholding_only_proceeding                                  0
# idncode                                            2.04461e+06
# strdescription_chicago                                  ASYLUM
# flag_decisionerror_strdes                                    0
# decision1_chicago                                         DENY
# grantordeny_chicago                                          1
# flag_decisionerror_idncaseproc                               0
# decision2_chicago                                         DENY
# grant_asylum_chicago                                         0
# grant_withhold_chicago                                       0
# grant_cat_chicago                                          NaN
# _mmasterappl                                       matched (3)
# strdescription_holger                                   ASYLUM
# decision1_holger                                          DENY
# grantordeny_holger                                           1
# decision2_holger                                          DENY
# grant_asylum_holger                                          0
# grant_withhold_holger                                        0
# grant_cat_holger                                           NaN
# _mmasterappl2                                      matched (3)
# adj_hearing_loc_code                                       NYX
# adj_base_city_code                                         NYC
# adj_time_start                                            1030
# adj_date                                                 14458
# adj_input_date                                           17395
# adj_osc_date                                             14158
# flag_earlystarttime                                          0
# eoirattyid                                                 NaN
# alienattyid                                               4214
# _mschedcompdate                                    matched (3)
# flag_mismatch_base_city                                      0
# flag_mismatch_hearing                                        0
# _mscheddatetime                                            NaN
# flag_datemismatch                                          NaN
# dec_col                                                      C
# dec_judge                                                    X
#
#                                                 1580690  \
# idncase                                         3449864
# nat                                                  MX
# case_type                                           DEP
# c_asy_type                                            I
# idnproceeding                                   1761791
# base_city_code                                      LOS
# hearing_loc_code                                    LOS
# dec_type                                              O
# dec_code                                              D
# other_comp
# attorney_flag                                         1
# ij_code                                             HPI
# tracid                                              190
# comp_year                                          1997
# comp_month                                            6
# comp_day                                             26
# comp_date                                         13691
# osc_year                                           1995
# osc_month                                             9
# osc_day                                              29
# osc_date                                          13055
# input_year                                         1995
# input_month                                          10
# input_day                                            17
# input_date                                        13073
# lawyer                                                1
# defensive                                             0
# affirmative                                           1
# case_type_string                            DEPORTATION
# _mcase                                      matched (3)
# dec_type_string                           ORAL DECISION
# _mdectype                                   matched (3)
# outcome_recorded_in_field                             C
# dec_string                                       DEPORT
# _mdecproceeddec                             matched (3)
# _mdecproceedoth                         master only (1)
# nat_string                                       MEXICO
# _mnat                                       matched (3)
# base_city_street                    606 SOUTH OLIVE ST.
# base_city_string                            LOS ANGELES
# base_city_state                                      CA
# base_city_zip5                                    90014
# base_city_zip4                                        0
# base_city_phone                             2.13894e+09
# _mbasecity                                  matched (3)
# hearing_loc_string1             LOS ANGELES, CALIFORNIA
# hearing_loc_string2                   IMMIGRATION COURT
# hearing_loc_street                  606 SOUTH OLIVE ST.
# hearing_loc_city                            LOS ANGELES
# hearing_loc_state                                    CA
# hearing_loc_zip5                                  90014
# hearing_loc_phone                            2138942811
# _mhearingloc                                matched (3)
# judge_name_caps                          HENRY P. IPEMA
# _mlookupijcode                              matched (3)
# cityid                                               28
# judgeid                                             153
# natid                                               152
# venue_change                                          0
# deport                                                1
# relief_granted                                        0
# remove                                                0
# terminated                                            0
# voluntary_departure                                   0
# oral                                                  1
# written                                               0
# deport_form                                           0
# voluntary_form                                        0
# deportation_proceeding                                1
# exclusion_proceeding                                  0
# removal_proceeding                                    0
# asylum_only_proceeding                                0
# withholding_only_proceeding                           0
# idncode                                     1.72428e+06
# strdescription_chicago                           ASYLUM
# flag_decisionerror_strdes                             0
# decision1_chicago                             WITHDRAWN
# grantordeny_chicago                                 NaN
# flag_decisionerror_idncaseproc                        1
# decision2_chicago                             WITHDRAWN
# grant_asylum_chicago                                NaN
# grant_withhold_chicago                              NaN
# grant_cat_chicago                                   NaN
# _mmasterappl                                matched (3)
# strdescription_holger
# decision1_holger
# grantordeny_holger                                  NaN
# decision2_holger
# grant_asylum_holger                                 NaN
# grant_withhold_holger                               NaN
# grant_cat_holger                                    NaN
# _mmasterappl2                           master only (1)
# adj_hearing_loc_code                                LOS
# adj_base_city_code                                  LOS
# adj_time_start                                     1300
# adj_date                                          13691
# adj_input_date                                    17242
# adj_osc_date                                      13055
# flag_earlystarttime                                   0
# eoirattyid                                        15119
# alienattyid                                       15139
# _mschedcompdate                             matched (3)
# flag_mismatch_base_city                               0
# flag_mismatch_hearing                                 0
# _mscheddatetime                                     NaN
# flag_datemismatch                                   NaN
# dec_col                                               C
# dec_judge                                             D
#
#                                                        5094761
# idncase                                                4484207
# nat                                                         IN
# case_type                                                  RMV
# c_asy_type
# idnproceeding                                          3068358
# base_city_code                                             NOL
# hearing_loc_code                                           NOO
# dec_type
# dec_code
# other_comp                                                   T
# attorney_flag                                                1
# ij_code                                                    CLR
# tracid                                                     NaN
# comp_year                                                 2003
# comp_month                                                   3
# comp_day                                                    11
# comp_date                                                15775
# osc_year                                                  2003
# osc_month                                                    2
# osc_day                                                     18
# osc_date                                                 15754
# input_year                                                2003
# input_month                                                  2
# input_day                                                   28
# input_date                                               15764
# lawyer                                                       1
# defensive                                                  NaN
# affirmative                                                NaN
# case_type_string                                       REMOVAL
# _mcase                                             matched (3)
# dec_type_string
# _mdectype                                      master only (1)
# outcome_recorded_in_field                                    O
# dec_string                                            TRANSFER
# _mdecproceeddec                                master only (1)
# _mdecproceedoth                            missing updated (4)
# nat_string                                               INDIA
# _mnat                                              matched (3)
# base_city_street                1 CANAL PL, 365 CANAL ST, 2450
# base_city_string                                   NEW ORLEANS
# base_city_state                                             LA
# base_city_zip5                                           70130
# base_city_zip4                                               0
# base_city_phone                                    5.04589e+09
# _mbasecity                                         matched (3)
# hearing_loc_string1                      NEW ORLEANS DETENTION
# hearing_loc_string2                          IMMIGRATION COURT
# hearing_loc_street              1 CANAL PL, 365 CANAL ST 2450B
# hearing_loc_city                                   NEW ORLEANS
# hearing_loc_state                                           LA
# hearing_loc_zip5                                         70130
# hearing_loc_phone                                   5045893992
# _mhearingloc                                       matched (3)
# judge_name_caps                         CLERICAL TRANSFER CODE
# _mlookupijcode                                     matched (3)
# cityid                                                      33
# judgeid                                                     64
# natid                                                      106
# venue_change                                                 0
# deport                                                       0
# relief_granted                                               0
# remove                                                       0
# terminated                                                   0
# voluntary_departure                                          0
# oral                                                       NaN
# written                                                    NaN
# deport_form                                                NaN
# voluntary_form                                             NaN
# deportation_proceeding                                       0
# exclusion_proceeding                                         0
# removal_proceeding                                           1
# asylum_only_proceeding                                       0
# withholding_only_proceeding                                  0
# idncode                                            3.02338e+06
# strdescription_chicago
# flag_decisionerror_strdes                                  NaN
# decision1_chicago
# grantordeny_chicago                                        NaN
# flag_decisionerror_idncaseproc                             NaN
# decision2_chicago
# grant_asylum_chicago                                       NaN
# grant_withhold_chicago                                     NaN
# grant_cat_chicago                                          NaN
# _mmasterappl                                   master only (1)
# strdescription_holger
# decision1_holger
# grantordeny_holger                                         NaN
# decision2_holger
# grant_asylum_holger                                        NaN
# grant_withhold_holger                                      NaN
# grant_cat_holger                                           NaN
# _mmasterappl2                                  master only (1)
# adj_hearing_loc_code                                       NOO
# adj_base_city_code                                         NOL
# adj_time_start                                             830
# adj_date                                                 15775
# adj_input_date                                           17122
# adj_osc_date                                             15754
# flag_earlystarttime                                          0
# eoirattyid                                               61750
# alienattyid                                               8179
# _mschedcompdate                                master only (1)
# flag_mismatch_base_city                                      0
# flag_mismatch_hearing                                        0
# _mscheddatetime                            missing updated (4)
# flag_datemismatch                                            0
# dec_col                                                      C
# dec_judge

# %%
dchen_selected_features = ['idncase', 'idnproceeding', 'nat_string', 'ij_code', 'attorney_flag',
                           'lawyer', 'defensive', 'affirmative', 
                           'oral', 'written', 'base_city_code', 'base_city_state', 
                           'hearing_loc_city', 'hearing_loc_code', 'hearing_loc_state', 'venue_change', 
                           'comp_year', 'comp_month', 'comp_day', 
                           'osc_year', 'osc_month', 'osc_day', 'input_year', 'input_month', 'input_day',
                           'adj_time_start', 'flag_earlystarttime', 
                           'flag_mismatch_base_city', 'flag_mismatch_hearing', 'flag_datemismatch',
                           'case_type_string', 'dec_type_string', 'dec_string', 
                           'deport', 'relief_granted', 'remove', 'terminated', 'voluntary_departure', 
                           'deport_form', 'voluntary_form', 'deportation_proceeding', 
                           'exclusion_proceeding', 'removal_proceeding', 'asylum_only_proceeding', 
                           'withholding_only_proceeding']

# %%
# merge with master proceedings 
appeals_with_master = appeals_deduped.merge(master_dchen[dchen_selected_features], how='left', 
                                            left_on=['idncase', 'idnProceeding'], right_on=['idncase', 'idnproceeding'])\
                                     .drop(['idnproceeding_y', 'case_type_string_y'], axis=1)\
                                     .rename(columns={'idnproceeding_x': 'idnproceeding', 
                                                      'case_type_string_x': 'case_type_string'})
appeals_with_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 253906 entries, 0 to 253905
# Data columns (total 71 columns):
# idnAppeal                      253906 non-null int64
# idncase                        253906 non-null int64
# idnProceeding                  253906 non-null int64
# strAppealCategory              253906 non-null object
# strAppealType                  253906 non-null object
# datAppealFiled                 253850 non-null object
# strFiledBy                     253901 non-null object
# datAttorneyE27                 178834 non-null object
# datBIADecision                 253906 non-null object
# strBIADecision                 253906 non-null object
# strBIADecisionType             247517 non-null object
# strCaseType                    253906 non-null object
# strLang                        253572 non-null object
# strNat                         253789 non-null object
# strProceedingIHP               123803 non-null object
# strCustody                     212262 non-null object
# strProbono                     578 non-null object
# datAppealFiled_dt              253850 non-null datetime64[ns]
# datBIADecision_dt              253906 non-null datetime64[ns]
# datAppealFiled_year            253850 non-null float64
# strAppealCategoryDesc          253667 non-null object
# strAppealTypeDesc              253906 non-null object
# strBIADecisionDesc             253906 non-null object
# strBIADecisionTypeDesc         247323 non-null object
# idnproceeding                  253906 non-null float64
# in_dunn                        253906 non-null float64
# case_type_string               253906 non-null object
# granted                        253906 non-null int64
# idnproceeding                  253906 non-null int32
# nat_string                     253906 non-null object
# ij_code                        253906 non-null object
# attorney_flag                  229718 non-null float64
# lawyer                         253906 non-null int8
# defensive                      248060 non-null float64
# affirmative                    248060 non-null float64
# oral                           253410 non-null float64
# written                        253410 non-null float64
# base_city_code                 253906 non-null object
# base_city_state                253906 non-null object
# hearing_loc_city               253906 non-null object
# hearing_loc_code               253906 non-null object
# hearing_loc_state              253906 non-null object
# venue_change                   253872 non-null float64
# comp_year                      253906 non-null int16
# comp_month                     253906 non-null int8
# comp_day                       253906 non-null int8
# osc_year                       253906 non-null float64
# osc_month                      253906 non-null float64
# osc_day                        253906 non-null float64
# input_year                     253895 non-null float64
# input_month                    253895 non-null float64
# input_day                      253895 non-null float64
# adj_time_start                 253902 non-null float64
# flag_earlystarttime            253906 non-null float64
# flag_mismatch_base_city        253906 non-null float64
# flag_mismatch_hearing          253905 non-null float64
# flag_datemismatch              19612 non-null float64
# dec_type_string                253906 non-null object
# dec_string                     253906 non-null object
# deport                         253872 non-null float64
# relief_granted                 253872 non-null float64
# remove                         253872 non-null float64
# terminated                     253872 non-null float64
# voluntary_departure            253872 non-null float64
# deport_form                    253410 non-null float64
# voluntary_form                 253410 non-null float64
# deportation_proceeding         253904 non-null float64
# exclusion_proceeding           253904 non-null float64
# removal_proceeding             253904 non-null float64
# asylum_only_proceeding         253904 non-null float64
# withholding_only_proceeding    253904 non-null float64
# dtypes: datetime64[ns](2), float64(32), int16(1), int32(1), int64(4), int8(3), object(28)
# memory usage: 132.0+ MB

# %%
appeals_with_master.groupby(['case_type_string']).size()
# Out:
# case_type_string
#                          2
# ASYLUM ONLY CASE      3744
# DEPORTATION          63442
# EXCLUSION            17211
# REMOVAL             168746
# WITHHOLDING ONLY       761
# dtype: int64

# %% [markdown]
# #### Add hearing sessions data

# %%
# TODO

# %% [markdown]
# #### Add judge bios data

# %%
# TODO

# %% [markdown]
# #### Output dataset for model training

# %%
# define features to output for training 
output_features = ['idnAppeal', 'nat_string', 'strCustody', 'strProbono', 'case_type_string',
                   'ij_code', 'lawyer', 'defensive', 'affirmative', 'oral', 'written', 
                   'comp_year', 'osc_year', 'input_year', 'datAppealFiled_year', 'granted']
appeals_final = appeals_with_master[output_features].copy()

# define mandatory features, without which data will be dropped 
mandatory_features = ['idnAppeal', 'granted', 'datAppealFiled_year', 'case_type_string'] 
appeals_final.dropna(subset=mandatory_features, inplace=True)

# generate output 
appeals_final.to_csv('data_for_model/data_for_model_2018-03-23.csv', index=False)
